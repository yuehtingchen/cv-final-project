# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
import torch
import torch.nn as nn

# %%
# setup matplotlib params
plt.rcParams["font.family"] = "Times"
plt.rcParams["font.size"] = 15

# %%
# use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image, ImageEnhance
import glob

# create custom dataset class
class OCTDataset(Dataset):
	def __init__(self, data_dir, label=0):
		self.data_dir = data_dir
		# transform to tensor, increase contrast, normalize, resize to 224x224
		self.transform = transforms.Compose(
			[transforms.ToTensor(),
			 transforms.CenterCrop((340, 340)),
			 transforms.Resize((224, 224), antialias=None),
			 transforms.GaussianBlur(kernel_size=3, sigma=1),
			 transforms.Normalize(mean=[0.4, 0.4, 0.4], std=[0.5, 0.5, 0.5])])

		# list .png files in data_dir
		self.img_list = glob.glob(os.path.join(data_dir, '*'))
		self.label = label

	def __len__(self):
		return len(self.img_list)

	def __getitem__(self, idx):
		img_path = self.img_list[idx]
		is_OS = img_path.split('/')[-1].split('_')[1] == 'OS'
		imgs_pth = sorted(glob.glob(os.path.join(img_path, '*Retina_o.png')))
		img = imgs_pth[0]

		img = Image.open(img).convert('RGB')
		img = ImageEnhance.Contrast(img).enhance(2)
		if is_OS:
			img = img.transpose(Image.FLIP_LEFT_RIGHT)

		img = self.transform(img)
		return img, self.label

# %%
# load data
AD = OCTDataset(data_dir='../data_all/All_AD_OCT', label=1)
AD_normal = OCTDataset(data_dir='../data_all/All_AD_normal_OCT', label=0)
CVD_normal = OCTDataset(data_dir='../data_all/All_CVD_normal_OCT', label=0)

# discard CVD data to balance dataset
# CVD_normal = torch.utils.data.Subset(CVD_normal, range(0, len(AD)-len(AD_normal)))

# mix data to create one dataset
dataset = torch.utils.data.ConcatDataset([AD, AD_normal, CVD_normal])

# %%
print('Number of images in dataset: ', len(dataset))
print('Positive samples: ', len(AD))
print('Negative samples: ', len(AD_normal) + len(CVD_normal))
# Out:
# Number of images in dataset:  289
# Positive samples:  134
# Negative samples:  155

# %%
# show some images
fig = plt.figure(figsize=(5, 5))
for i in range(4):
	img, label = dataset[i * 50]
	ax = fig.add_subplot(2, 2, i+1)
	ax.imshow(img.permute(1, 2, 0).numpy())
	ax.set_axis_off()
	ax.set_title(f'label: {label}')

# save image
plt.tight_layout()
plt.savefig('plots/data.png', dpi=500)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# load pretrained resent models
from torchvision.models import resnet18, resnet34, resnet50, resnet101, resnet152

# create custom resnet model
class ResNet(nn.Module):
	def __init__(self, model_name):
		super(ResNet, self).__init__()
		if model_name == 'resnet18':
			self.model = resnet18(weights="IMAGENET1K_V1")
		elif model_name == 'resnet34':
			self.model = resnet34(weights="IMAGENET1K_V1")
		elif model_name == 'resnet50':
			self.model = resnet50(weights="IMAGENET1K_V1")
		elif model_name == 'resnet101':
			self.model = resnet101(weights="IMAGENET1K_V1")
		elif model_name == 'resnet152':
			self.model = resnet152(weights="IMAGENET1K_V1")
		else:
			raise Exception('Invalid model name')

		# change the last layer
		self.model.fc = nn.Linear(self.model.fc.in_features, 1)
		self.model.sigmoid = nn.Sigmoid()

	def forward(self, x):
		x = self.model(x)
		return self.model.sigmoid(x)

# %%
# define vanilla CNN model
class CNN(nn.Module):
	def __init__(self):
		super(CNN, self).__init__()

		self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
		self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
		self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
		self.conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)

		self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

		self.fc1 = nn.Linear(128 * 14 * 14, 512)
		self.fc2 = nn.Linear(512, 1)
		self.relu = nn.ReLU()
		self.sigmoid = nn.Sigmoid()

	def forward(self, x):
		x = self.pool(self.relu(self.conv1(x)))
		x = self.pool(self.relu(self.conv2(x)))
		x = self.pool(self.relu(self.conv3(x)))
		x = self.pool(self.relu(self.conv4(x)))

		x = x.view(-1, 128 * 14 * 14)
		x = self.relu(self.fc1(x))
		x = self.sigmoid(self.fc2(x))
		return x

# %%
labels = []
for _, label in dataset:
	labels.append(label)

# %%
# perform 5 fold cross validation
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# create 5 folds
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
folds = list(skf.split(np.zeros(len(labels)), labels))

# %%
# train model
train_loss_list = []
train_acc_list = []
train_precision_list = []
train_recall_list = []
train_f1_list = []

val_loss_list = []
val_acc_list = []
val_precision_list = []
val_recall_list = []
val_f1_list = []

def train_resnet(model_name, warmup_epochs=3, fine_tune_epochs=None, lr=1e-4, batch_size=32):
	fold_count = 1

	# perform 10 fold cross validation
	for train_idx, test_idx in folds:
		# reset model
		if model_name == 'cnn':
			model = CNN()
			model = model.to(device)
		else:
			model = ResNet(model_name)
			model = model.to(device)

		# define loss function and optimizer
		criterion = nn.BCELoss()
		optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

		best_loss = np.inf

		# split train to train and validation
		train_idx, val_idx = train_test_split(train_idx, test_size=0.2, random_state=42)

		# create dataloaders
		train_loader = DataLoader(torch.utils.data.Subset(dataset, train_idx), batch_size=batch_size, shuffle=True)
		val_loader = DataLoader(torch.utils.data.Subset(dataset, val_idx), batch_size=batch_size, shuffle=True)


		if fine_tune_epochs is None or fine_tune_epochs == 0:
			fine_tune_epochs = 0
		else:
			# freeze all layers except last
			for param in model.parameters():
				param.requires_grad = False
			for param in model.model.fc.parameters():
				param.requires_grad = True

		# train model
		for epoch in range(warmup_epochs + fine_tune_epochs):
			# unfreeze all layers after warmup
			if epoch == warmup_epochs:
				for param in model.parameters():
					param.requires_grad = True

			# train
			model.train()
			train_loss = 0
			train_acc = 0
			train_precision = 0
			train_recall = 0
			train_f1 = 0
			for img, label in train_loader:
				img = img.to(device)
				label = label.to(device)

				# forward pass
				output = model(img)
				loss = criterion(output, label.float().unsqueeze(1))

				# backward pass
				optimizer.zero_grad()
				loss.backward()
				optimizer.step()

				# calculate metrics
				train_loss += loss.item()
				train_acc += accuracy_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int))
				train_precision += precision_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int), zero_division=1)
				train_recall += recall_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int), zero_division=1)
				train_f1 += f1_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int), zero_division=1)

			# calculate average metrics
			train_loss /= len(train_loader)
			train_acc /= len(train_loader)
			train_precision /= len(train_loader)
			train_recall /= len(train_loader)
			train_f1 /= len(train_loader)

			train_loss_list.append(train_loss)
			train_acc_list.append(train_acc)
			train_precision_list.append(train_precision)
			train_recall_list.append(train_recall)
			train_f1_list.append(train_f1)

			# evaluate model on validation set
			model.eval()

			val_loss = 0
			val_acc = 0
			val_precision = 0
			val_recall = 0
			val_f1 = 0
			for img, label in val_loader:
				img = img.to(device)
				label = label.to(device)

				# forward pass
				output = model(img)
				loss = criterion(output, label.float().unsqueeze(1))

				# calculate metrics
				val_loss += loss.item()
				val_acc += accuracy_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int))
				val_precision += precision_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int), zero_division=1)
				val_recall += recall_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int), zero_division=1)
				val_f1 += f1_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int), zero_division=1)

			# calculate average metrics
			val_loss /= len(val_loader)
			val_acc /= len(val_loader)
			val_precision /= len(val_loader)
			val_recall /= len(val_loader)
			val_f1 /= len(val_loader)

			val_loss_list.append(val_loss)
			val_acc_list.append(val_acc)
			val_precision_list.append(val_precision)
			val_recall_list.append(val_recall)
			val_f1_list.append(val_f1)

			# print metrics
			print(f'Epoch: {epoch+1}\n\
			Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Train Precision: {train_precision:.4f}, Train Recall: {train_recall:.4f}, Train F1: {train_f1:.4f}\n\
			Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, Val Precision: {val_precision:.4f}, Val Recall: {val_recall:.4f}, Val F1: {val_f1:.4f}')
			print()

			# save best model
			if val_loss < best_loss:
				best_loss = val_loss
				torch.save(model.state_dict(), f'{model_name}_{fold_count}.pt')

		fold_count += 1

# %%
# evaluate model on test set
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc

test_acc_list = []
test_precision_list = []
test_recall_list = []
test_f1_list = []
test_auc_list = []

def test_resnet(model_name, batch_size=32):
	for i in range(1, 6):
		# load model
		if model_name == 'cnn':
			model = CNN()
			model.load_state_dict(torch.load(f'{model_name}_{i}.pt'))
			model = model.to(device)
		else:
			model = ResNet(model_name)
			model.load_state_dict(torch.load(f'{model_name}_{i}.pt'))
			model = model.to(device)

		model.eval()

		test_loader = DataLoader(torch.utils.data.Subset(dataset, folds[i-1][1]), batch_size=batch_size, shuffle=True)

		y_true = []
		y_pred = []

		test_acc = 0
		test_precision = 0
		test_recall = 0
		test_f1 = 0

		for img, label in test_loader:
			img = img.to(device)
			label = label.to(device)

			# forward pass
			output = model(img)

			# calculate metrics
			y_true.extend(label.cpu().numpy())
			y_pred.extend((output.cpu().detach().numpy() > 0.5).astype(int))

			# calculate metrics
			test_acc += accuracy_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int))
			test_precision += precision_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int))
			test_recall += recall_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int))
			test_f1 += f1_score(label.cpu().numpy(), (output.cpu().detach().numpy() > 0.5).astype(int))

		# calculate average metrics
		test_acc /= len(test_loader)
		test_precision /= len(test_loader)
		test_recall /= len(test_loader)
		test_f1 /= len(test_loader)

		test_acc_list.append(test_acc)
		test_precision_list.append(test_precision)
		test_recall_list.append(test_recall)
		test_f1_list.append(test_f1)

		# print metrics
		print(f'Fold: {i} Test Acc: {test_acc:.4f}, Test Precision: {test_precision:.4f}, Test Recall: {test_recall:.4f}, Test F1: {test_f1:.4f}')
		print('--------------------------------------------------')


		cm = confusion_matrix(y_true, y_pred)
		sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
		# add title
		plt.title(f'Test Dataset Confusion Matrix for Fold {i}')
		plt.xlabel('Predicted')
		plt.ylabel('True')
		plt.savefig(f'plots/{model_name}/confusion_matrix_{i}.png', dpi=300)
		# clear plot
		plt.clf()

		# auc-roc curve
		fpr, tpr, _ = roc_curve(y_true, y_pred)
		# calculate AUC
		auc_score = auc(fpr, tpr)
		test_auc_list.append(auc_score)

		# plot the roc curve for the model
		plt.plot(fpr, tpr, marker='.', label=f'AUC = {auc_score:.4f}')
		# axis labels
		plt.xlabel('False Positive Rate')
		plt.ylabel('True Positive Rate')
		# show the legend
		plt.legend()
		# save the plot
		plt.savefig(f'plots/{model_name}/roc_curve_{i}.png', dpi=300)
		# clear plot
		plt.clf()

# %% [markdown]
# ### Train Resnet18

# %%
train_loss_list = []
train_acc_list = []
train_precision_list = []
train_recall_list = []
train_f1_list = []

val_loss_list = []
val_acc_list = []
val_precision_list = []
val_recall_list = []
val_f1_list = []

warmup_epochs = 10
fine_tune_epochs = 10

# train resnet18
train_resnet('resnet18', warmup_epochs=warmup_epochs, fine_tune_epochs=fine_tune_epochs, lr=1e-5, batch_size=8)
# Out:
# Epoch: 1
# 			Train Loss: 0.7429, Train Acc: 0.4408, Train Precision: 0.5079, Train Recall: 0.4748, Train F1: 0.4784
# 			Val Loss: 0.6600, Val Acc: 0.6350, Val Precision: 0.6207, Val Recall: 1.0000, Val F1: 0.7564
#
# Epoch: 2
# 			Train Loss: 0.7057, Train Acc: 0.4649, Train Precision: 0.5368, Train Recall: 0.5395, Train F1: 0.5139
# 			Val Loss: 0.6410, Val Acc: 0.6500, Val Precision: 0.6429, Val Recall: 1.0000, Val F1: 0.7629
#
# Epoch: 3
# 			Train Loss: 0.7328, Train Acc: 0.4320, Train Precision: 0.4781, Train Recall: 0.5096, Train F1: 0.4617
# 			Val Loss: 0.7383, Val Acc: 0.6050, Val Precision: 0.5979, Val Recall: 1.0000, Val F1: 0.7396
#
# Epoch: 4
# 			Train Loss: 0.7142, Train Acc: 0.4912, Train Precision: 0.5521, Train Recall: 0.5756, Train F1: 0.5389
# 			Val Loss: 0.7154, Val Acc: 0.6350, Val Precision: 0.6410, Val Recall: 0.9667, Val F1: 0.7413
#
# Epoch: 5
# 			Train Loss: 0.7305, Train Acc: 0.4342, Train Precision: 0.5123, Train Recall: 0.5235, Train F1: 0.5040
# 			Val Loss: 0.7184, Val Acc: 0.4800, Val Precision: 0.5533, Val Recall: 0.6433, Val F1: 0.5911
#
# Epoch: 6
# 			Train Loss: 0.7097, Train Acc: 0.4759, Train Precision: 0.5538, Train Recall: 0.6415, Train F1: 0.5696
# 			Val Loss: 0.7124, Val Acc: 0.4400, Val Precision: 0.5271, Val Recall: 0.4733, Val F1: 0.4667
#
# Epoch: 7
# 			Train Loss: 0.7084, Train Acc: 0.4868, Train Precision: 0.5449, Train Recall: 0.6119, Train F1: 0.5611
# 			Val Loss: 0.7111, Val Acc: 0.5050, Val Precision: 0.6167, Val Recall: 0.5700, Val F1: 0.5708
#
# Epoch: 8
# 			Train Loss: 0.7182, Train Acc: 0.4978, Train Precision: 0.5526, Train Recall: 0.6857, Train F1: 0.6032
# 			Val Loss: 0.7037, Val Acc: 0.5450, Val Precision: 0.5933, Val Recall: 0.7400, Val F1: 0.6456
#
# Epoch: 9
# 			Train Loss: 0.7174, Train Acc: 0.4759, Train Precision: 0.5360, Train Recall: 0.6596, Train F1: 0.5770
# 			Val Loss: 0.6948, Val Acc: 0.5750, Val Precision: 0.6200, Val Recall: 0.7200, Val F1: 0.6513
#
# Epoch: 10
# 			Train Loss: 0.7040, Train Acc: 0.5154, Train Precision: 0.5556, Train Recall: 0.7323, Train F1: 0.6188
# 			Val Loss: 0.7189, Val Acc: 0.5300, Val Precision: 0.6238, Val Recall: 0.7276, Val F1: 0.6193
#
# Epoch: 11
# 			Train Loss: 0.6965, Train Acc: 0.5307, Train Precision: 0.5716, Train Recall: 0.7535, Train F1: 0.6354
# 			Val Loss: 0.6735, Val Acc: 0.5800, Val Precision: 0.6262, Val Recall: 0.6467, Val F1: 0.6255
#
# Epoch: 12
# 			Train Loss: 0.5673, Train Acc: 0.7259, Train Precision: 0.7306, Train Recall: 0.8657, Train F1: 0.7716
# 			Val Loss: 0.6349, Val Acc: 0.7100, Val Precision: 0.7167, Val Recall: 0.8000, Val F1: 0.7459
#
# Epoch: 13
# 			Train Loss: 0.5157, Train Acc: 0.8026, Train Precision: 0.8244, Train Recall: 0.8788, Train F1: 0.8190
# 			Val Loss: 0.6073, Val Acc: 0.6100, Val Precision: 0.6500, Val Recall: 0.6095, Val F1: 0.6138
#
# Epoch: 14
# 			Train Loss: 0.4551, Train Acc: 0.8706, Train Precision: 0.9105, Train Recall: 0.8962, Train F1: 0.8813
# 			Val Loss: 0.5928, Val Acc: 0.6250, Val Precision: 0.6800, Val Recall: 0.6267, Val F1: 0.6394
#
# Epoch: 15
# 			Train Loss: 0.4091, Train Acc: 0.9013, Train Precision: 0.9193, Train Recall: 0.9091, Train F1: 0.9028
# 			Val Loss: 0.5985, Val Acc: 0.6200, Val Precision: 0.7167, Val Recall: 0.5933, Val F1: 0.6321
#
# Epoch: 16
# 			Train Loss: 0.3539, Train Acc: 0.9079, Train Precision: 0.9202, Train Recall: 0.9368, Train F1: 0.9129
# 			Val Loss: 0.5961, Val Acc: 0.6350, Val Precision: 0.7033, Val Recall: 0.6233, Val F1: 0.6400
#
# Epoch: 17
# 			Train Loss: 0.3102, Train Acc: 0.9605, Train Precision: 0.9789, Train Recall: 0.9674, Train F1: 0.9685
# 			Val Loss: 0.6062, Val Acc: 0.6200, Val Precision: 0.7000, Val Recall: 0.5943, Val F1: 0.6255
#
# Epoch: 18
# 			Train Loss: 0.2740, Train Acc: 0.9803, Train Precision: 0.9868, Train Recall: 0.9825, Train F1: 0.9820
# 			Val Loss: 0.5974, Val Acc: 0.6850, Val Precision: 0.8000, Val Recall: 0.6367, Val F1: 0.7033
#
# Epoch: 19
# 			Train Loss: 0.2388, Train Acc: 0.9803, Train Precision: 1.0000, Train Recall: 0.9754, Train F1: 0.9866
# 			Val Loss: 0.5880, Val Acc: 0.6700, Val Precision: 0.7800, Val Recall: 0.6343, Val F1: 0.6766
#
# Epoch: 20
# 			Train Loss: 0.2413, Train Acc: 0.9474, Train Precision: 0.9825, Train Recall: 0.9486, Train F1: 0.9574
# 			Val Loss: 0.6122, Val Acc: 0.6450, Val Precision: 0.7367, Val Recall: 0.6167, Val F1: 0.6591
#
# Epoch: 1
# 			Train Loss: 0.7497, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.6998
# 			Val Loss: 0.6389, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7449
#
# Epoch: 2
# 			Train Loss: 0.7258, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7266
# 			Val Loss: 0.7222, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 3
# 			Train Loss: 0.7260, Train Acc: 0.5746, Train Precision: 0.5783, Train Recall: 0.9895, Train F1: 0.7047
# 			Val Loss: 0.7236, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7062
#
# Epoch: 4
# 			Train Loss: 0.7275, Train Acc: 0.5592, Train Precision: 0.5639, Train Recall: 0.9925, Train F1: 0.6895
# 			Val Loss: 0.7134, Val Acc: 0.5800, Val Precision: 0.5893, Val Recall: 0.9333, Val F1: 0.7131
#
# Epoch: 5
# 			Train Loss: 0.7042, Train Acc: 0.5789, Train Precision: 0.5858, Train Recall: 0.9588, Train F1: 0.7134
# 			Val Loss: 0.6698, Val Acc: 0.5700, Val Precision: 0.5843, Val Recall: 0.9100, Val F1: 0.7093
#
# Epoch: 6
# 			Train Loss: 0.6961, Train Acc: 0.5987, Train Precision: 0.5959, Train Recall: 0.9895, Train F1: 0.7141
# 			Val Loss: 0.6693, Val Acc: 0.5700, Val Precision: 0.5843, Val Recall: 0.9600, Val F1: 0.7177
#
# Epoch: 7
# 			Train Loss: 0.7173, Train Acc: 0.5636, Train Precision: 0.5683, Train Recall: 0.9807, Train F1: 0.6917
# 			Val Loss: 0.6738, Val Acc: 0.5400, Val Precision: 0.5500, Val Recall: 0.9000, Val F1: 0.6738
#
# Epoch: 8
# 			Train Loss: 0.7228, Train Acc: 0.5636, Train Precision: 0.5692, Train Recall: 0.9714, Train F1: 0.7042
# 			Val Loss: 0.6636, Val Acc: 0.5700, Val Precision: 0.5843, Val Recall: 0.9600, Val F1: 0.7124
#
# Epoch: 9
# 			Train Loss: 0.6881, Train Acc: 0.5746, Train Precision: 0.5755, Train Recall: 0.9649, Train F1: 0.7087
# 			Val Loss: 0.6464, Val Acc: 0.6100, Val Precision: 0.6171, Val Recall: 0.9600, Val F1: 0.7292
#
# Epoch: 10
# 			Train Loss: 0.6803, Train Acc: 0.5811, Train Precision: 0.5877, Train Recall: 0.9714, Train F1: 0.7140
# 			Val Loss: 0.6701, Val Acc: 0.5700, Val Precision: 0.5833, Val Recall: 0.9333, Val F1: 0.7077
#
# Epoch: 11
# 			Train Loss: 0.6800, Train Acc: 0.6184, Train Precision: 0.6109, Train Recall: 0.9868, Train F1: 0.7400
# 			Val Loss: 0.6216, Val Acc: 0.5850, Val Precision: 0.6107, Val Recall: 0.9314, Val F1: 0.7100
#
# Epoch: 12
# 			Train Loss: 0.5924, Train Acc: 0.6689, Train Precision: 0.6482, Train Recall: 0.9759, Train F1: 0.7548
# 			Val Loss: 0.5838, Val Acc: 0.5950, Val Precision: 0.6429, Val Recall: 0.7867, Val F1: 0.6858
#
# Epoch: 13
# 			Train Loss: 0.5494, Train Acc: 0.7478, Train Precision: 0.7201, Train Recall: 0.9613, Train F1: 0.7837
# 			Val Loss: 0.5872, Val Acc: 0.6450, Val Precision: 0.7333, Val Recall: 0.6733, Val F1: 0.6700
#
# Epoch: 14
# 			Train Loss: 0.4659, Train Acc: 0.8377, Train Precision: 0.7907, Train Recall: 0.9837, Train F1: 0.8550
# 			Val Loss: 0.5753, Val Acc: 0.6600, Val Precision: 0.7500, Val Recall: 0.7067, Val F1: 0.7169
#
# Epoch: 15
# 			Train Loss: 0.4265, Train Acc: 0.8882, Train Precision: 0.8675, Train Recall: 0.9696, Train F1: 0.8994
# 			Val Loss: 0.5940, Val Acc: 0.6450, Val Precision: 0.7333, Val Recall: 0.6533, Val F1: 0.6656
#
# Epoch: 16
# 			Train Loss: 0.3835, Train Acc: 0.8969, Train Precision: 0.8719, Train Recall: 0.9699, Train F1: 0.9009
# 			Val Loss: 0.5720, Val Acc: 0.6600, Val Precision: 0.7300, Val Recall: 0.6700, Val F1: 0.6863
#
# Epoch: 17
# 			Train Loss: 0.3000, Train Acc: 0.9605, Train Precision: 0.9632, Train Recall: 0.9774, Train F1: 0.9623
# 			Val Loss: 0.5911, Val Acc: 0.6050, Val Precision: 0.8000, Val Recall: 0.5833, Val F1: 0.6355
#
# Epoch: 18
# 			Train Loss: 0.2797, Train Acc: 0.9605, Train Precision: 0.9333, Train Recall: 0.9912, Train F1: 0.9552
# 			Val Loss: 0.5823, Val Acc: 0.6100, Val Precision: 0.7600, Val Recall: 0.4943, Val F1: 0.5876
#
# Epoch: 19
# 			Train Loss: 0.2303, Train Acc: 0.9934, Train Precision: 0.9868, Train Recall: 1.0000, Train F1: 0.9925
# 			Val Loss: 0.6155, Val Acc: 0.6100, Val Precision: 0.8933, Val Recall: 0.3667, Val F1: 0.4359
#
# Epoch: 20
# 			Train Loss: 0.2357, Train Acc: 0.9803, Train Precision: 0.9825, Train Recall: 0.9868, Train F1: 0.9820
# 			Val Loss: 0.6032, Val Acc: 0.6450, Val Precision: 0.7000, Val Recall: 0.6800, Val F1: 0.6410
#
# Epoch: 1
# 			Train Loss: 0.6873, Train Acc: 0.5614, Train Precision: 0.5717, Train Recall: 0.9632, Train F1: 0.7052
# 			Val Loss: 0.6856, Val Acc: 0.5550, Val Precision: 0.5548, Val Recall: 0.5524, Val F1: 0.5337
#
# Epoch: 2
# 			Train Loss: 0.7016, Train Acc: 0.5570, Train Precision: 0.5664, Train Recall: 0.9825, Train F1: 0.7016
# 			Val Loss: 0.6409, Val Acc: 0.6350, Val Precision: 0.6243, Val Recall: 0.9500, Val F1: 0.7492
#
# Epoch: 3
# 			Train Loss: 0.6981, Train Acc: 0.5482, Train Precision: 0.5661, Train Recall: 0.9439, Train F1: 0.6935
# 			Val Loss: 0.6125, Val Acc: 0.6350, Val Precision: 0.6286, Val Recall: 0.9714, Val F1: 0.7275
#
# Epoch: 4
# 			Train Loss: 0.6986, Train Acc: 0.5241, Train Precision: 0.5504, Train Recall: 0.8969, Train F1: 0.6679
# 			Val Loss: 0.6177, Val Acc: 0.6850, Val Precision: 0.6562, Val Recall: 0.9267, Val F1: 0.7564
#
# Epoch: 5
# 			Train Loss: 0.6974, Train Acc: 0.5658, Train Precision: 0.5799, Train Recall: 0.9368, Train F1: 0.7027
# 			Val Loss: 0.6218, Val Acc: 0.6200, Val Precision: 0.6143, Val Recall: 0.9667, Val F1: 0.7347
#
# Epoch: 6
# 			Train Loss: 0.6814, Train Acc: 0.5614, Train Precision: 0.5764, Train Recall: 0.9495, Train F1: 0.6999
# 			Val Loss: 0.6282, Val Acc: 0.6600, Val Precision: 0.6719, Val Recall: 0.8933, Val F1: 0.7358
#
# Epoch: 7
# 			Train Loss: 0.6735, Train Acc: 0.5746, Train Precision: 0.5818, Train Recall: 0.9293, Train F1: 0.7071
# 			Val Loss: 0.6389, Val Acc: 0.6350, Val Precision: 0.6336, Val Recall: 0.9214, Val F1: 0.7253
#
# Epoch: 8
# 			Train Loss: 0.7059, Train Acc: 0.5197, Train Precision: 0.5426, Train Recall: 0.9123, Train F1: 0.6596
# 			Val Loss: 0.6258, Val Acc: 0.6100, Val Precision: 0.6667, Val Recall: 0.8833, Val F1: 0.7314
#
# Epoch: 9
# 			Train Loss: 0.6994, Train Acc: 0.5548, Train Precision: 0.5789, Train Recall: 0.9020, Train F1: 0.6839
# 			Val Loss: 0.6389, Val Acc: 0.5950, Val Precision: 0.6114, Val Recall: 0.8767, Val F1: 0.7160
#
# Epoch: 10
# 			Train Loss: 0.6770, Train Acc: 0.5789, Train Precision: 0.5871, Train Recall: 0.9246, Train F1: 0.7030
# 			Val Loss: 0.6337, Val Acc: 0.5450, Val Precision: 0.6319, Val Recall: 0.7767, Val F1: 0.6364
#
# Epoch: 11
# 			Train Loss: 0.6774, Train Acc: 0.5702, Train Precision: 0.5861, Train Recall: 0.8912, Train F1: 0.6971
# 			Val Loss: 0.6105, Val Acc: 0.6450, Val Precision: 0.6800, Val Recall: 0.7762, Val F1: 0.6955
#
# Epoch: 12
# 			Train Loss: 0.5958, Train Acc: 0.6864, Train Precision: 0.6873, Train Recall: 0.9113, Train F1: 0.7576
# 			Val Loss: 0.6225, Val Acc: 0.7200, Val Precision: 0.7933, Val Recall: 0.6533, Val F1: 0.7121
#
# Epoch: 13
# 			Train Loss: 0.5006, Train Acc: 0.8224, Train Precision: 0.8018, Train Recall: 0.9439, Train F1: 0.8510
# 			Val Loss: 0.6056, Val Acc: 0.7100, Val Precision: 0.7500, Val Recall: 0.6800, Val F1: 0.6981
#
# Epoch: 14
# 			Train Loss: 0.4562, Train Acc: 0.8947, Train Precision: 0.8715, Train Recall: 0.9719, Train F1: 0.8994
# 			Val Loss: 0.6092, Val Acc: 0.6600, Val Precision: 0.8000, Val Recall: 0.5500, Val F1: 0.6500
#
# Epoch: 15
# 			Train Loss: 0.4639, Train Acc: 0.8465, Train Precision: 0.8540, Train Recall: 0.9386, Train F1: 0.8436
# 			Val Loss: 0.5977, Val Acc: 0.7100, Val Precision: 0.6933, Val Recall: 0.5167, Val F1: 0.5912
#
# Epoch: 16
# 			Train Loss: 0.3501, Train Acc: 0.9561, Train Precision: 0.9500, Train Recall: 0.9807, Train F1: 0.9585
# 			Val Loss: 0.6039, Val Acc: 0.7200, Val Precision: 0.8600, Val Recall: 0.6933, Val F1: 0.7566
#
# Epoch: 17
# 			Train Loss: 0.3628, Train Acc: 0.9298, Train Precision: 0.9158, Train Recall: 0.9762, Train F1: 0.9317
# 			Val Loss: 0.5855, Val Acc: 0.7000, Val Precision: 0.7500, Val Recall: 0.6367, Val F1: 0.6833
#
# Epoch: 18
# 			Train Loss: 0.2883, Train Acc: 0.9737, Train Precision: 0.9737, Train Recall: 0.9837, Train F1: 0.9736
# 			Val Loss: 0.6050, Val Acc: 0.6700, Val Precision: 0.8762, Val Recall: 0.5667, Val F1: 0.6476
#
# Epoch: 19
# 			Train Loss: 0.2646, Train Acc: 0.9934, Train Precision: 1.0000, Train Recall: 0.9925, Train F1: 0.9960
# 			Val Loss: 0.5941, Val Acc: 0.6700, Val Precision: 0.6667, Val Recall: 0.4738, Val F1: 0.5507
#
# Epoch: 20
# 			Train Loss: 0.2151, Train Acc: 0.9934, Train Precision: 0.9825, Train Recall: 1.0000, Train F1: 0.9895
# 			Val Loss: 0.6202, Val Acc: 0.6650, Val Precision: 0.7500, Val Recall: 0.5700, Val F1: 0.6381
#
# Epoch: 1
# 			Train Loss: 0.6499, Train Acc: 0.6601, Train Precision: 0.6895, Train Recall: 0.8187, Train F1: 0.7262
# 			Val Loss: 0.6987, Val Acc: 0.5350, Val Precision: 0.7000, Val Recall: 0.3095, Val F1: 0.3800
#
# Epoch: 2
# 			Train Loss: 0.6423, Train Acc: 0.6096, Train Precision: 0.6633, Train Recall: 0.7764, Train F1: 0.6906
# 			Val Loss: 0.6865, Val Acc: 0.4800, Val Precision: 0.6833, Val Recall: 0.4833, Val F1: 0.4990
#
# Epoch: 3
# 			Train Loss: 0.6427, Train Acc: 0.6206, Train Precision: 0.6328, Train Recall: 0.7591, Train F1: 0.6652
# 			Val Loss: 0.6769, Val Acc: 0.4900, Val Precision: 0.5917, Val Recall: 0.6357, Val F1: 0.5738
#
# Epoch: 4
# 			Train Loss: 0.6460, Train Acc: 0.6491, Train Precision: 0.6589, Train Recall: 0.8704, Train F1: 0.7277
# 			Val Loss: 0.6555, Val Acc: 0.6350, Val Precision: 0.6326, Val Recall: 0.9600, Val F1: 0.7583
#
# Epoch: 5
# 			Train Loss: 0.6534, Train Acc: 0.6360, Train Precision: 0.6476, Train Recall: 0.8163, Train F1: 0.6819
# 			Val Loss: 0.6630, Val Acc: 0.5800, Val Precision: 0.6076, Val Recall: 0.7433, Val F1: 0.6606
#
# Epoch: 6
# 			Train Loss: 0.6362, Train Acc: 0.6623, Train Precision: 0.6660, Train Recall: 0.8701, Train F1: 0.7308
# 			Val Loss: 0.6565, Val Acc: 0.6450, Val Precision: 0.6667, Val Recall: 0.7667, Val F1: 0.6818
#
# Epoch: 7
# 			Train Loss: 0.6382, Train Acc: 0.6425, Train Precision: 0.6743, Train Recall: 0.7939, Train F1: 0.7153
# 			Val Loss: 0.6539, Val Acc: 0.6100, Val Precision: 0.7095, Val Recall: 0.7357, Val F1: 0.6729
#
# Epoch: 8
# 			Train Loss: 0.6393, Train Acc: 0.6382, Train Precision: 0.6509, Train Recall: 0.8459, Train F1: 0.7182
# 			Val Loss: 0.6526, Val Acc: 0.6600, Val Precision: 0.6729, Val Recall: 0.8467, Val F1: 0.7386
#
# Epoch: 9
# 			Train Loss: 0.6433, Train Acc: 0.6535, Train Precision: 0.6661, Train Recall: 0.8876, Train F1: 0.7370
# 			Val Loss: 0.6464, Val Acc: 0.6450, Val Precision: 0.5714, Val Recall: 0.7029, Val F1: 0.6172
#
# Epoch: 10
# 			Train Loss: 0.6187, Train Acc: 0.6864, Train Precision: 0.6726, Train Recall: 0.9179, Train F1: 0.7559
# 			Val Loss: 0.6526, Val Acc: 0.6350, Val Precision: 0.6629, Val Recall: 0.7867, Val F1: 0.6986
#
# Epoch: 11
# 			Train Loss: 0.6647, Train Acc: 0.5132, Train Precision: 0.5809, Train Recall: 0.7224, Train F1: 0.5938
# 			Val Loss: 0.6447, Val Acc: 0.6600, Val Precision: 0.6867, Val Recall: 0.8300, Val F1: 0.7354
#
# Epoch: 12
# 			Train Loss: 0.5463, Train Acc: 0.7697, Train Precision: 0.7798, Train Recall: 0.8736, Train F1: 0.8020
# 			Val Loss: 0.6406, Val Acc: 0.6600, Val Precision: 0.6748, Val Recall: 0.7700, Val F1: 0.7128
#
# Epoch: 13
# 			Train Loss: 0.4652, Train Acc: 0.8882, Train Precision: 0.8789, Train Recall: 0.9482, Train F1: 0.9011
# 			Val Loss: 0.6463, Val Acc: 0.6050, Val Precision: 0.6633, Val Recall: 0.7833, Val F1: 0.6800
#
# Epoch: 14
# 			Train Loss: 0.3916, Train Acc: 0.9211, Train Precision: 0.9254, Train Recall: 0.9564, Train F1: 0.9322
# 			Val Loss: 0.6384, Val Acc: 0.6600, Val Precision: 0.7143, Val Recall: 0.7762, Val F1: 0.7178
#
# Epoch: 15
# 			Train Loss: 0.3479, Train Acc: 0.9474, Train Precision: 0.9675, Train Recall: 0.9539, Train F1: 0.9573
# 			Val Loss: 0.6328, Val Acc: 0.6850, Val Precision: 0.7200, Val Recall: 0.7629, Val F1: 0.7338
#
# Epoch: 16
# 			Train Loss: 0.3311, Train Acc: 0.9298, Train Precision: 0.9561, Train Recall: 0.9336, Train F1: 0.9345
# 			Val Loss: 0.6419, Val Acc: 0.6850, Val Precision: 0.7133, Val Recall: 0.6714, Val F1: 0.6779
#
# Epoch: 17
# 			Train Loss: 0.2864, Train Acc: 0.9737, Train Precision: 0.9649, Train Recall: 0.9850, Train F1: 0.9649
# 			Val Loss: 0.6385, Val Acc: 0.6600, Val Precision: 0.7167, Val Recall: 0.5800, Val F1: 0.6314
#
# Epoch: 18
# 			Train Loss: 0.2671, Train Acc: 0.9539, Train Precision: 0.9649, Train Recall: 0.9581, Train F1: 0.9502
# 			Val Loss: 0.6748, Val Acc: 0.5150, Val Precision: 0.6000, Val Recall: 0.4450, Val F1: 0.4805
#
# Epoch: 19
# 			Train Loss: 0.2098, Train Acc: 0.9803, Train Precision: 0.9868, Train Recall: 0.9850, Train F1: 0.9837
# 			Val Loss: 0.6439, Val Acc: 0.7100, Val Precision: 0.6933, Val Recall: 0.7981, Val F1: 0.7332
#
# Epoch: 20
# 			Train Loss: 0.1988, Train Acc: 0.9737, Train Precision: 0.9605, Train Recall: 0.9912, Train F1: 0.9636
# 			Val Loss: 0.6636, Val Acc: 0.6550, Val Precision: 0.7000, Val Recall: 0.6962, Val F1: 0.6418
#
# Epoch: 1
# 			Train Loss: 0.6953, Train Acc: 0.5373, Train Precision: 0.5669, Train Recall: 0.8306, Train F1: 0.6498
# 			Val Loss: 0.6793, Val Acc: 0.5850, Val Precision: 0.6533, Val Recall: 0.6833, Val F1: 0.6502
#
# Epoch: 2
# 			Train Loss: 0.6873, Train Acc: 0.5833, Train Precision: 0.5919, Train Recall: 0.8845, Train F1: 0.6932
# 			Val Loss: 0.7143, Val Acc: 0.4700, Val Precision: 0.5500, Val Recall: 0.7800, Val F1: 0.6348
#
# Epoch: 3
# 			Train Loss: 0.6844, Train Acc: 0.5636, Train Precision: 0.5777, Train Recall: 0.9079, Train F1: 0.6890
# 			Val Loss: 0.7217, Val Acc: 0.5400, Val Precision: 0.5750, Val Recall: 0.8714, Val F1: 0.6718
#
# Epoch: 4
# 			Train Loss: 0.6697, Train Acc: 0.5746, Train Precision: 0.6049, Train Recall: 0.8752, Train F1: 0.6912
# 			Val Loss: 0.6809, Val Acc: 0.5600, Val Precision: 0.6533, Val Recall: 0.7867, Val F1: 0.6648
#
# Epoch: 5
# 			Train Loss: 0.6759, Train Acc: 0.5724, Train Precision: 0.6012, Train Recall: 0.8274, Train F1: 0.6745
# 			Val Loss: 0.6864, Val Acc: 0.5950, Val Precision: 0.6210, Val Recall: 0.8433, Val F1: 0.7076
#
# Epoch: 6
# 			Train Loss: 0.6839, Train Acc: 0.5746, Train Precision: 0.6063, Train Recall: 0.8701, Train F1: 0.6807
# 			Val Loss: 0.6949, Val Acc: 0.5700, Val Precision: 0.6067, Val Recall: 0.8000, Val F1: 0.6845
#
# Epoch: 7
# 			Train Loss: 0.6745, Train Acc: 0.5329, Train Precision: 0.5717, Train Recall: 0.8228, Train F1: 0.6646
# 			Val Loss: 0.6936, Val Acc: 0.5950, Val Precision: 0.6393, Val Recall: 0.8643, Val F1: 0.6981
#
# Epoch: 8
# 			Train Loss: 0.6979, Train Acc: 0.5329, Train Precision: 0.5611, Train Recall: 0.8679, Train F1: 0.6570
# 			Val Loss: 0.6855, Val Acc: 0.6500, Val Precision: 0.6429, Val Recall: 0.9667, Val F1: 0.7526
#
# Epoch: 9
# 			Train Loss: 0.6769, Train Acc: 0.5921, Train Precision: 0.6096, Train Recall: 0.8776, Train F1: 0.6995
# 			Val Loss: 0.6935, Val Acc: 0.5950, Val Precision: 0.6021, Val Recall: 0.8600, Val F1: 0.7038
#
# Epoch: 10
# 			Train Loss: 0.6683, Train Acc: 0.6250, Train Precision: 0.6203, Train Recall: 0.9114, Train F1: 0.7281
# 			Val Loss: 0.6944, Val Acc: 0.5950, Val Precision: 0.6200, Val Recall: 0.8533, Val F1: 0.6924
#
# Epoch: 11
# 			Train Loss: 0.6764, Train Acc: 0.5373, Train Precision: 0.5722, Train Recall: 0.8501, Train F1: 0.6604
# 			Val Loss: 0.6449, Val Acc: 0.5450, Val Precision: 0.5929, Val Recall: 0.6167, Val F1: 0.5953
#
# Epoch: 12
# 			Train Loss: 0.5549, Train Acc: 0.7785, Train Precision: 0.7727, Train Recall: 0.9271, Train F1: 0.8208
# 			Val Loss: 0.5975, Val Acc: 0.6350, Val Precision: 0.7333, Val Recall: 0.6667, Val F1: 0.6803
#
# Epoch: 13
# 			Train Loss: 0.4719, Train Acc: 0.8509, Train Precision: 0.8495, Train Recall: 0.9223, Train F1: 0.8714
# 			Val Loss: 0.5976, Val Acc: 0.6600, Val Precision: 0.8833, Val Recall: 0.5000, Val F1: 0.6267
#
# Epoch: 14
# 			Train Loss: 0.4337, Train Acc: 0.8969, Train Precision: 0.9070, Train Recall: 0.9325, Train F1: 0.9065
# 			Val Loss: 0.5919, Val Acc: 0.6450, Val Precision: 0.9000, Val Recall: 0.4543, Val F1: 0.5121
#
# Epoch: 15
# 			Train Loss: 0.4290, Train Acc: 0.8487, Train Precision: 0.8614, Train Recall: 0.9486, Train F1: 0.8637
# 			Val Loss: 0.5805, Val Acc: 0.6850, Val Precision: 0.8500, Val Recall: 0.5500, Val F1: 0.6571
#
# Epoch: 16
# 			Train Loss: 0.3496, Train Acc: 0.9342, Train Precision: 0.9175, Train Recall: 0.9803, Train F1: 0.9373
# 			Val Loss: 0.5978, Val Acc: 0.7000, Val Precision: 0.9500, Val Recall: 0.5833, Val F1: 0.6586
#
# Epoch: 17
# 			Train Loss: 0.3329, Train Acc: 0.9539, Train Precision: 0.9404, Train Recall: 0.9850, Train F1: 0.9456
# 			Val Loss: 0.6084, Val Acc: 0.6700, Val Precision: 0.9000, Val Recall: 0.5571, Val F1: 0.6532
#
# Epoch: 18
# 			Train Loss: 0.3041, Train Acc: 0.9408, Train Precision: 0.9368, Train Recall: 0.9718, Train F1: 0.9434
# 			Val Loss: 0.6216, Val Acc: 0.6450, Val Precision: 0.9000, Val Recall: 0.4000, Val F1: 0.5048
#
# Epoch: 19
# 			Train Loss: 0.2802, Train Acc: 0.9605, Train Precision: 0.9561, Train Recall: 0.9749, Train F1: 0.9608
# 			Val Loss: 0.6109, Val Acc: 0.6600, Val Precision: 0.9000, Val Recall: 0.4700, Val F1: 0.5905
#
# Epoch: 20
# 			Train Loss: 0.2242, Train Acc: 0.9803, Train Precision: 0.9605, Train Recall: 1.0000, Train F1: 0.9684
# 			Val Loss: 0.6050, Val Acc: 0.7100, Val Precision: 0.9333, Val Recall: 0.4700, Val F1: 0.5703

# %%
num_epochs = warmup_epochs + fine_tune_epochs

train_loss_list = np.array(train_loss_list).reshape(5, num_epochs)
train_acc_list = np.array(train_acc_list).reshape(5, num_epochs)
train_precision_list = np.array(train_precision_list).reshape(5, num_epochs)
train_recall_list = np.array(train_recall_list).reshape(5, num_epochs)
train_f1_list = np.array(train_f1_list).reshape(5, num_epochs)

val_loss_list = np.array(val_loss_list).reshape(5, num_epochs)
val_acc_list = np.array(val_acc_list).reshape(5, num_epochs)
val_precision_list = np.array(val_precision_list).reshape(5, num_epochs)
val_recall_list = np.array(val_recall_list).reshape(5, num_epochs)
val_f1_list = np.array(val_f1_list).reshape(5, num_epochs)

# %%
# plot average loss across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_loss_list, axis=0)
std_values = np.std(train_loss_list, axis=0)

plt.plot(epochs, mean_values, label='Train Loss', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(val_loss_list, axis=0)
std_values = np.std(val_loss_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Loss', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
# limit x tick to be integers
plt.xticks(np.arange(1, num_epochs+1, 2.0))
# plt.ylim(0, 1.2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('ResNet18 Loss over Epochs')
plt.legend()
plt.savefig('plots/resnet18/loss.png', dpi=300)

# %%
# plot average accuracy across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_acc_list, axis=0)
std_values = np.std(train_acc_list, axis=0)

plt.plot(epochs, mean_values, label='Train Accuracy', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

mean_values = np.mean(val_acc_list, axis=0)
std_values = np.std(val_acc_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Accuracy', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
# limit x tick to be integers
plt.xticks(np.arange(1, num_epochs+1, 2.0))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('ResNet18 accuracy over Epochs')
plt.legend()
plt.savefig('plots/resnet18/accuracy.png', dpi=300)

# %%
# plot average precision across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_precision_list, axis=0)
std_values = np.std(train_precision_list, axis=0)

plt.plot(epochs, mean_values, label='Train Precision', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

mean_values = np.mean(val_precision_list, axis=0)
std_values = np.std(val_precision_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Precision', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
# limit x tick to be integers
plt.xticks(np.arange(1, num_epochs+1, 2.0))
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('ResNet18 Precision over Epochs')
plt.legend()
plt.savefig('plots/resnet18/precision.png', dpi=300)

# %%
# plot average recall across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_recall_list, axis=0)
std_values = np.std(train_recall_list, axis=0)

plt.plot(epochs, mean_values, label='Train Recall', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

mean_values = np.mean(val_recall_list, axis=0)
std_values = np.std(val_recall_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Recall', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
# limit x tick to be integers
plt.xticks(np.arange(1, num_epochs+1, 2.0))
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('ResNet18 Recall over Epochs')
plt.legend()
plt.savefig('plots/resnet18/recall.png', dpi=300)

# %%
# save metrics
np.save('plots/resnet18/train_loss.npy', train_loss_list)
np.save('plots/resnet18/train_acc.npy', train_acc_list)
np.save('plots/resnet18/train_precision.npy', train_precision_list)
np.save('plots/resnet18/train_recall.npy', train_recall_list)
np.save('plots/resnet18/train_f1.npy', train_f1_list)

np.save('plots/resnet18/val_loss.npy', val_loss_list)
np.save('plots/resnet18/val_acc.npy', val_acc_list)
np.save('plots/resnet18/val_precision.npy', val_precision_list)
np.save('plots/resnet18/val_recall.npy', val_recall_list)
np.save('plots/resnet18/val_f1.npy', val_f1_list)

# %%
test_acc_list = []
test_precision_list = []
test_recall_list = []
test_f1_list = []
test_auc_list = []

# test resnet18
test_resnet('resnet18')
# Out:
# Fold: 1 Test Acc: 0.6897, Test Precision: 0.7146, Test Recall: 0.7735, Test F1: 0.7429
# --------------------------------------------------
# Fold: 2 Test Acc: 0.6250, Test Precision: 0.6500, Test Recall: 0.7571, Test F1: 0.6941
# --------------------------------------------------
# Fold: 3 Test Acc: 0.6853, Test Precision: 0.7418, Test Recall: 0.7222, Test F1: 0.7317
# --------------------------------------------------
# Fold: 4 Test Acc: 0.7165, Test Precision: 0.8750, Test Recall: 0.6333, Test F1: 0.7333
# --------------------------------------------------
# Fold: 5 Test Acc: 0.5312, Test Precision: 0.5658, Test Recall: 0.4586, Test F1: 0.4976
# --------------------------------------------------

# %%
# save metrics
np.save('plots/resnet18/test_acc.npy', test_acc_list)
np.save('plots/resnet18/test_precision.npy', test_precision_list)
np.save('plots/resnet18/test_recall.npy', test_recall_list)
np.save('plots/resnet18/test_f1.npy', test_f1_list)
np.save('plots/resnet18/test_auc.npy', test_auc_list)

# %%
# show some images and predictions
test_loader = DataLoader(torch.utils.data.Subset(dataset, folds[0][1]), batch_size=4, shuffle=True)
model = ResNet('resnet18')
model.load_state_dict(torch.load(f'resnet18_1.pt'))

dataiter = iter(test_loader)
img, label = next(dataiter)
img = img.to(device)
label = label.to(device)
output = model(img)

fig = plt.figure(figsize=(5, 5))
for i in range(4):
	ax = fig.add_subplot(2, 2, i+1)
	ax.imshow(img[i].permute(1, 2, 0).cpu().numpy())
	ax.set_axis_off()
	ax.set_title(f'Label: {label[i].cpu().numpy()}, Pred: {(output[i].cpu().detach().numpy())[0]:.2f}')

# add title
plt.suptitle('Test Dataset Predictions')
# save image
plt.savefig('plots/resnet18/predictions.png', dpi=300)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# calculate average metrics for all folds print in latex format
print('&${0:.2f}\pm{1:.2f}$'.format(np.mean(test_acc_list), np.std(test_acc_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_precision_list), np.std(test_precision_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_recall_list), np.std(test_recall_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_f1_list), np.std(test_f1_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_auc_list), np.std(test_auc_list)))
# Out:
# &$0.65\pm0.07$ &$0.71\pm0.10$ &$0.67\pm0.12$ &$0.68\pm0.09$ &$0.65\pm0.06$

# %%
# calculate average metrics for all folds
print('Average Test Accuracy: ', np.mean(test_acc_list), np.std(test_acc_list))
print('Average Test Precision: ', np.mean(test_precision_list), np.std(test_precision_list))
print('Average Test Recall: ', np.mean(test_recall_list), np.std(test_recall_list))
print('Average Test F1: ', np.mean(test_f1_list), np.std(test_f1_list))
print('Average Test AUC: ', np.mean(test_auc_list), np.std(test_auc_list))
# Out:
# Average Test Accuracy:  0.6495535714285714 0.06629126073623884
# Average Test Precision:  0.7094532007380305 0.10262058628522057
# Average Test Recall:  0.6689748882008943 0.11580053542022371
# Average Test F1:  0.6799323620995448 0.0926707818780576
# Average Test AUC:  0.6466629179787075 0.06179221906660159

# %% [markdown]
# ### Train ResNet50

# %%
train_loss_list = []
train_acc_list = []
train_precision_list = []
train_recall_list = []
train_f1_list = []

val_loss_list = []
val_acc_list = []
val_precision_list = []
val_recall_list = []
val_f1_list = []

# train resnet18
warmup_epochs = 10
fine_tune_epochs = 8

# train resnet18
train_resnet('resnet50', warmup_epochs=warmup_epochs, fine_tune_epochs=fine_tune_epochs, lr=1e-5, batch_size=8)
# Out:
# Epoch: 1
# 			Train Loss: 0.6979, Train Acc: 0.5044, Train Precision: 0.5542, Train Recall: 0.8262, Train F1: 0.6395
# 			Val Loss: 0.6874, Val Acc: 0.5950, Val Precision: 0.6443, Val Recall: 0.7667, Val F1: 0.6752
#
# Epoch: 2
# 			Train Loss: 0.6887, Train Acc: 0.5855, Train Precision: 0.5912, Train Recall: 0.9451, Train F1: 0.7153
# 			Val Loss: 0.6787, Val Acc: 0.5550, Val Precision: 0.5800, Val Recall: 0.9381, Val F1: 0.6929
#
# Epoch: 3
# 			Train Loss: 0.6880, Train Acc: 0.5482, Train Precision: 0.5736, Train Recall: 0.9464, Train F1: 0.6896
# 			Val Loss: 0.6928, Val Acc: 0.4600, Val Precision: 0.5200, Val Recall: 0.4867, Val F1: 0.4823
#
# Epoch: 4
# 			Train Loss: 0.6845, Train Acc: 0.5439, Train Precision: 0.5627, Train Recall: 0.9241, Train F1: 0.6803
# 			Val Loss: 0.6809, Val Acc: 0.5300, Val Precision: 0.5417, Val Recall: 0.8200, Val F1: 0.6387
#
# Epoch: 5
# 			Train Loss: 0.6833, Train Acc: 0.5592, Train Precision: 0.5724, Train Recall: 0.9246, Train F1: 0.6889
# 			Val Loss: 0.6751, Val Acc: 0.5850, Val Precision: 0.6393, Val Recall: 0.9100, Val F1: 0.7215
#
# Epoch: 6
# 			Train Loss: 0.6805, Train Acc: 0.5680, Train Precision: 0.5774, Train Recall: 0.9820, Train F1: 0.7081
# 			Val Loss: 0.6713, Val Acc: 0.5850, Val Precision: 0.5957, Val Recall: 0.9500, Val F1: 0.7279
#
# Epoch: 7
# 			Train Loss: 0.6817, Train Acc: 0.5614, Train Precision: 0.5758, Train Recall: 0.9548, Train F1: 0.7012
# 			Val Loss: 0.6808, Val Acc: 0.6350, Val Precision: 0.6207, Val Recall: 1.0000, Val F1: 0.7564
#
# Epoch: 8
# 			Train Loss: 0.6802, Train Acc: 0.5768, Train Precision: 0.5749, Train Recall: 0.9868, Train F1: 0.7082
# 			Val Loss: 0.6850, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7214
#
# Epoch: 9
# 			Train Loss: 0.6776, Train Acc: 0.5811, Train Precision: 0.5821, Train Recall: 0.9925, Train F1: 0.7087
# 			Val Loss: 0.6723, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 0.9500, Val F1: 0.7388
#
# Epoch: 10
# 			Train Loss: 0.6766, Train Acc: 0.5855, Train Precision: 0.5912, Train Recall: 0.9789, Train F1: 0.7205
# 			Val Loss: 0.6841, Val Acc: 0.5700, Val Precision: 0.5807, Val Recall: 0.9500, Val F1: 0.7110
#
# Epoch: 11
# 			Train Loss: 0.6646, Train Acc: 0.6009, Train Precision: 0.5962, Train Recall: 0.9820, Train F1: 0.7303
# 			Val Loss: 0.6810, Val Acc: 0.5150, Val Precision: 0.5714, Val Recall: 0.8214, Val F1: 0.6344
#
# Epoch: 12
# 			Train Loss: 0.5836, Train Acc: 0.7390, Train Precision: 0.7066, Train Recall: 0.9807, Train F1: 0.8063
# 			Val Loss: 0.6606, Val Acc: 0.4950, Val Precision: 0.5564, Val Recall: 0.7143, Val F1: 0.6054
#
# Epoch: 13
# 			Train Loss: 0.5411, Train Acc: 0.7829, Train Precision: 0.8000, Train Recall: 0.8833, Train F1: 0.8078
# 			Val Loss: 0.6702, Val Acc: 0.4800, Val Precision: 0.5357, Val Recall: 0.6314, Val F1: 0.5548
#
# Epoch: 14
# 			Train Loss: 0.4663, Train Acc: 0.8816, Train Precision: 0.8860, Train Recall: 0.9274, Train F1: 0.8805
# 			Val Loss: 0.6825, Val Acc: 0.4900, Val Precision: 0.5867, Val Recall: 0.5900, Val F1: 0.5712
#
# Epoch: 15
# 			Train Loss: 0.4411, Train Acc: 0.8706, Train Precision: 0.8947, Train Recall: 0.8961, Train F1: 0.8718
# 			Val Loss: 0.6443, Val Acc: 0.4950, Val Precision: 0.5867, Val Recall: 0.5700, Val F1: 0.5643
#
# Epoch: 16
# 			Train Loss: 0.3310, Train Acc: 0.9474, Train Precision: 0.9553, Train Recall: 0.9674, Train F1: 0.9551
# 			Val Loss: 0.6657, Val Acc: 0.5200, Val Precision: 0.5900, Val Recall: 0.6567, Val F1: 0.6000
#
# Epoch: 17
# 			Train Loss: 0.2945, Train Acc: 0.9342, Train Precision: 0.9447, Train Recall: 0.9649, Train F1: 0.9351
# 			Val Loss: 0.7040, Val Acc: 0.5400, Val Precision: 0.6300, Val Recall: 0.5800, Val F1: 0.5933
#
# Epoch: 18
# 			Train Loss: 0.2320, Train Acc: 0.9759, Train Precision: 1.0000, Train Recall: 0.9737, Train F1: 0.9847
# 			Val Loss: 0.7329, Val Acc: 0.6300, Val Precision: 0.8000, Val Recall: 0.4771, Val F1: 0.5722
#
# Epoch: 1
# 			Train Loss: 0.6965, Train Acc: 0.5241, Train Precision: 0.5511, Train Recall: 0.8798, Train F1: 0.6665
# 			Val Loss: 0.6535, Val Acc: 0.6850, Val Precision: 0.7076, Val Recall: 0.8800, Val F1: 0.7701
#
# Epoch: 2
# 			Train Loss: 0.6854, Train Acc: 0.5548, Train Precision: 0.5714, Train Recall: 0.9175, Train F1: 0.6944
# 			Val Loss: 0.6823, Val Acc: 0.5800, Val Precision: 0.5650, Val Recall: 0.8333, Val F1: 0.6519
#
# Epoch: 3
# 			Train Loss: 0.6905, Train Acc: 0.5636, Train Precision: 0.5692, Train Recall: 0.9500, Train F1: 0.7039
# 			Val Loss: 0.7003, Val Acc: 0.5050, Val Precision: 0.5517, Val Recall: 0.7143, Val F1: 0.6072
#
# Epoch: 4
# 			Train Loss: 0.6846, Train Acc: 0.5680, Train Precision: 0.5724, Train Recall: 0.9737, Train F1: 0.7134
# 			Val Loss: 0.6803, Val Acc: 0.5950, Val Precision: 0.5986, Val Recall: 0.9667, Val F1: 0.7286
#
# Epoch: 5
# 			Train Loss: 0.6860, Train Acc: 0.5724, Train Precision: 0.5836, Train Recall: 0.9649, Train F1: 0.7068
# 			Val Loss: 0.6940, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6944
#
# Epoch: 6
# 			Train Loss: 0.6820, Train Acc: 0.5636, Train Precision: 0.5683, Train Recall: 0.9763, Train F1: 0.7036
# 			Val Loss: 0.6762, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7388
#
# Epoch: 7
# 			Train Loss: 0.6806, Train Acc: 0.5746, Train Precision: 0.5774, Train Recall: 0.9868, Train F1: 0.7214
# 			Val Loss: 0.6834, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7201
#
# Epoch: 8
# 			Train Loss: 0.6782, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 0.9895, Train F1: 0.7126
# 			Val Loss: 0.6756, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 9
# 			Train Loss: 0.6805, Train Acc: 0.5746, Train Precision: 0.5793, Train Recall: 0.9781, Train F1: 0.7180
# 			Val Loss: 0.6912, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6944
#
# Epoch: 10
# 			Train Loss: 0.6823, Train Acc: 0.5746, Train Precision: 0.5802, Train Recall: 0.9925, Train F1: 0.7202
# 			Val Loss: 0.6706, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 11
# 			Train Loss: 0.6693, Train Acc: 0.5504, Train Precision: 0.5645, Train Recall: 0.9588, Train F1: 0.6946
# 			Val Loss: 0.6405, Val Acc: 0.6200, Val Precision: 0.6129, Val Recall: 1.0000, Val F1: 0.7395
#
# Epoch: 12
# 			Train Loss: 0.5913, Train Acc: 0.6601, Train Precision: 0.6719, Train Recall: 0.8828, Train F1: 0.7312
# 			Val Loss: 0.6272, Val Acc: 0.6100, Val Precision: 0.6362, Val Recall: 0.8000, Val F1: 0.6943
#
# Epoch: 13
# 			Train Loss: 0.5482, Train Acc: 0.8246, Train Precision: 0.8095, Train Recall: 0.9543, Train F1: 0.8467
# 			Val Loss: 0.6223, Val Acc: 0.6050, Val Precision: 0.7017, Val Recall: 0.7300, Val F1: 0.6526
#
# Epoch: 14
# 			Train Loss: 0.4636, Train Acc: 0.9342, Train Precision: 0.9281, Train Recall: 0.9749, Train F1: 0.9367
# 			Val Loss: 0.6368, Val Acc: 0.5950, Val Precision: 0.6443, Val Recall: 0.6943, Val F1: 0.6500
#
# Epoch: 15
# 			Train Loss: 0.3705, Train Acc: 0.9342, Train Precision: 0.9272, Train Recall: 0.9674, Train F1: 0.9373
# 			Val Loss: 0.6456, Val Acc: 0.5800, Val Precision: 0.7400, Val Recall: 0.5962, Val F1: 0.5510
#
# Epoch: 16
# 			Train Loss: 0.2559, Train Acc: 0.9868, Train Precision: 1.0000, Train Recall: 0.9825, Train F1: 0.9904
# 			Val Loss: 0.6564, Val Acc: 0.6100, Val Precision: 0.6633, Val Recall: 0.6376, Val F1: 0.6286
#
# Epoch: 17
# 			Train Loss: 0.1818, Train Acc: 0.9868, Train Precision: 1.0000, Train Recall: 0.9807, Train F1: 0.9894
# 			Val Loss: 0.7549, Val Acc: 0.5450, Val Precision: 0.7333, Val Recall: 0.4067, Val F1: 0.5165
#
# Epoch: 18
# 			Train Loss: 0.1738, Train Acc: 0.9868, Train Precision: 0.9825, Train Recall: 0.9925, Train F1: 0.9854
# 			Val Loss: 0.8041, Val Acc: 0.5700, Val Precision: 0.7667, Val Recall: 0.3829, Val F1: 0.4672
#
# Epoch: 1
# 			Train Loss: 0.6851, Train Acc: 0.5636, Train Precision: 0.5875, Train Recall: 0.7706, Train F1: 0.6570
# 			Val Loss: 0.6838, Val Acc: 0.5450, Val Precision: 0.5700, Val Recall: 0.9200, Val F1: 0.6935
#
# Epoch: 2
# 			Train Loss: 0.6884, Train Acc: 0.5439, Train Precision: 0.5714, Train Recall: 0.8272, Train F1: 0.6593
# 			Val Loss: 0.6868, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7419
#
# Epoch: 3
# 			Train Loss: 0.6821, Train Acc: 0.5811, Train Precision: 0.5862, Train Recall: 0.9320, Train F1: 0.7092
# 			Val Loss: 0.6752, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7449
#
# Epoch: 4
# 			Train Loss: 0.6771, Train Acc: 0.5702, Train Precision: 0.5805, Train Recall: 0.9469, Train F1: 0.6992
# 			Val Loss: 0.6625, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 5
# 			Train Loss: 0.6754, Train Acc: 0.5746, Train Precision: 0.5783, Train Recall: 0.9583, Train F1: 0.7111
# 			Val Loss: 0.6695, Val Acc: 0.6200, Val Precision: 0.6000, Val Recall: 1.0000, Val F1: 0.7368
#
# Epoch: 6
# 			Train Loss: 0.6723, Train Acc: 0.5680, Train Precision: 0.5746, Train Recall: 0.9763, Train F1: 0.7148
# 			Val Loss: 0.6604, Val Acc: 0.6200, Val Precision: 0.6093, Val Recall: 1.0000, Val F1: 0.7451
#
# Epoch: 7
# 			Train Loss: 0.6775, Train Acc: 0.5570, Train Precision: 0.5645, Train Recall: 0.9789, Train F1: 0.7022
# 			Val Loss: 0.6648, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 8
# 			Train Loss: 0.6828, Train Acc: 0.5833, Train Precision: 0.5746, Train Recall: 1.0000, Train F1: 0.7035
# 			Val Loss: 0.6624, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7201
#
# Epoch: 9
# 			Train Loss: 0.6732, Train Acc: 0.5855, Train Precision: 0.5874, Train Recall: 0.9684, Train F1: 0.7143
# 			Val Loss: 0.6614, Val Acc: 0.6350, Val Precision: 0.6250, Val Recall: 1.0000, Val F1: 0.7596
#
# Epoch: 10
# 			Train Loss: 0.6821, Train Acc: 0.5724, Train Precision: 0.5667, Train Recall: 1.0000, Train F1: 0.6933
# 			Val Loss: 0.6635, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7201
#
# Epoch: 11
# 			Train Loss: 0.6601, Train Acc: 0.5987, Train Precision: 0.6046, Train Recall: 0.9684, Train F1: 0.7267
# 			Val Loss: 0.6499, Val Acc: 0.6050, Val Precision: 0.5979, Val Recall: 1.0000, Val F1: 0.7396
#
# Epoch: 12
# 			Train Loss: 0.5989, Train Acc: 0.7346, Train Precision: 0.7068, Train Recall: 0.9424, Train F1: 0.7731
# 			Val Loss: 0.6366, Val Acc: 0.5950, Val Precision: 0.6248, Val Recall: 0.8467, Val F1: 0.6905
#
# Epoch: 13
# 			Train Loss: 0.5363, Train Acc: 0.8026, Train Precision: 0.8132, Train Recall: 0.9411, Train F1: 0.8464
# 			Val Loss: 0.6220, Val Acc: 0.5850, Val Precision: 0.6333, Val Recall: 0.7800, Val F1: 0.6820
#
# Epoch: 14
# 			Train Loss: 0.4690, Train Acc: 0.8750, Train Precision: 0.8766, Train Recall: 0.9439, Train F1: 0.8966
# 			Val Loss: 0.6278, Val Acc: 0.5800, Val Precision: 0.6171, Val Recall: 0.7667, Val F1: 0.6733
#
# Epoch: 15
# 			Train Loss: 0.3983, Train Acc: 0.9167, Train Precision: 0.9158, Train Recall: 0.9555, Train F1: 0.9233
# 			Val Loss: 0.6208, Val Acc: 0.6100, Val Precision: 0.7467, Val Recall: 0.5000, Val F1: 0.5135
#
# Epoch: 16
# 			Train Loss: 0.3061, Train Acc: 0.9803, Train Precision: 0.9763, Train Recall: 0.9895, Train F1: 0.9820
# 			Val Loss: 0.6532, Val Acc: 0.6050, Val Precision: 0.7429, Val Recall: 0.5357, Val F1: 0.5933
#
# Epoch: 17
# 			Train Loss: 0.2373, Train Acc: 0.9605, Train Precision: 1.0000, Train Recall: 0.9480, Train F1: 0.9693
# 			Val Loss: 0.6503, Val Acc: 0.6100, Val Precision: 0.6333, Val Recall: 0.5300, Val F1: 0.5714
#
# Epoch: 18
# 			Train Loss: 0.2057, Train Acc: 0.9693, Train Precision: 1.0000, Train Recall: 0.9671, Train F1: 0.9812
# 			Val Loss: 0.6735, Val Acc: 0.5950, Val Precision: 0.9333, Val Recall: 0.3405, Val F1: 0.4356
#
# Epoch: 1
# 			Train Loss: 0.7164, Train Acc: 0.4583, Train Precision: 0.6491, Train Recall: 0.1722, Train F1: 0.2508
# 			Val Loss: 0.7192, Val Acc: 0.4700, Val Precision: 0.8000, Val Recall: 0.1667, Val F1: 0.2171
#
# Epoch: 2
# 			Train Loss: 0.7003, Train Acc: 0.4890, Train Precision: 0.6404, Train Recall: 0.2496, Train F1: 0.3529
# 			Val Loss: 0.6876, Val Acc: 0.5150, Val Precision: 0.7000, Val Recall: 0.2900, Val F1: 0.3976
#
# Epoch: 3
# 			Train Loss: 0.6931, Train Acc: 0.5395, Train Precision: 0.6351, Train Recall: 0.5306, Train F1: 0.5448
# 			Val Loss: 0.6787, Val Acc: 0.5550, Val Precision: 0.7000, Val Recall: 0.4367, Val F1: 0.5300
#
# Epoch: 4
# 			Train Loss: 0.6788, Train Acc: 0.6228, Train Precision: 0.6982, Train Recall: 0.7100, Train F1: 0.6785
# 			Val Loss: 0.7039, Val Acc: 0.5050, Val Precision: 0.6667, Val Recall: 0.4333, Val F1: 0.5000
#
# Epoch: 5
# 			Train Loss: 0.6912, Train Acc: 0.5110, Train Precision: 0.5511, Train Recall: 0.7952, Train F1: 0.6065
# 			Val Loss: 0.6980, Val Acc: 0.5200, Val Precision: 0.5133, Val Recall: 0.5800, Val F1: 0.5400
#
# Epoch: 6
# 			Train Loss: 0.6830, Train Acc: 0.5570, Train Precision: 0.5774, Train Recall: 0.8402, Train F1: 0.6741
# 			Val Loss: 0.6834, Val Acc: 0.6600, Val Precision: 0.6583, Val Recall: 0.8550, Val F1: 0.7079
#
# Epoch: 7
# 			Train Loss: 0.6788, Train Acc: 0.5614, Train Precision: 0.5902, Train Recall: 0.9109, Train F1: 0.6914
# 			Val Loss: 0.6814, Val Acc: 0.6050, Val Precision: 0.6821, Val Recall: 0.8800, Val F1: 0.7136
#
# Epoch: 8
# 			Train Loss: 0.6802, Train Acc: 0.5548, Train Precision: 0.5786, Train Recall: 0.8837, Train F1: 0.6758
# 			Val Loss: 0.6798, Val Acc: 0.6300, Val Precision: 0.6167, Val Recall: 0.9381, Val F1: 0.7090
#
# Epoch: 9
# 			Train Loss: 0.6718, Train Acc: 0.5855, Train Precision: 0.5927, Train Recall: 0.9719, Train F1: 0.7161
# 			Val Loss: 0.6690, Val Acc: 0.6500, Val Precision: 0.6750, Val Recall: 0.9267, Val F1: 0.7280
#
# Epoch: 10
# 			Train Loss: 0.6745, Train Acc: 0.5439, Train Precision: 0.5589, Train Recall: 0.9412, Train F1: 0.6873
# 			Val Loss: 0.6751, Val Acc: 0.5950, Val Precision: 0.6057, Val Recall: 0.9100, Val F1: 0.7225
#
# Epoch: 11
# 			Train Loss: 0.6640, Train Acc: 0.5855, Train Precision: 0.5940, Train Recall: 0.9820, Train F1: 0.7132
# 			Val Loss: 0.6557, Val Acc: 0.6850, Val Precision: 0.7167, Val Recall: 0.8362, Val F1: 0.7596
#
# Epoch: 12
# 			Train Loss: 0.5987, Train Acc: 0.7127, Train Precision: 0.6952, Train Recall: 0.9456, Train F1: 0.7884
# 			Val Loss: 0.6404, Val Acc: 0.6400, Val Precision: 0.6933, Val Recall: 0.8433, Val F1: 0.7111
#
# Epoch: 13
# 			Train Loss: 0.5606, Train Acc: 0.7939, Train Precision: 0.7518, Train Recall: 0.9632, Train F1: 0.8023
# 			Val Loss: 0.6266, Val Acc: 0.6450, Val Precision: 0.7100, Val Recall: 0.7400, Val F1: 0.6790
#
# Epoch: 14
# 			Train Loss: 0.4779, Train Acc: 0.8882, Train Precision: 0.8807, Train Recall: 0.9581, Train F1: 0.9057
# 			Val Loss: 0.6205, Val Acc: 0.5950, Val Precision: 0.7800, Val Recall: 0.5300, Val F1: 0.5754
#
# Epoch: 15
# 			Train Loss: 0.4255, Train Acc: 0.8684, Train Precision: 0.8658, Train Recall: 0.9524, Train F1: 0.8746
# 			Val Loss: 0.6129, Val Acc: 0.5950, Val Precision: 0.7500, Val Recall: 0.5200, Val F1: 0.6032
#
# Epoch: 16
# 			Train Loss: 0.3157, Train Acc: 0.9737, Train Precision: 0.9632, Train Recall: 0.9925, Train F1: 0.9751
# 			Val Loss: 0.5959, Val Acc: 0.5950, Val Precision: 0.7500, Val Recall: 0.4867, Val F1: 0.5810
#
# Epoch: 17
# 			Train Loss: 0.2549, Train Acc: 0.9605, Train Precision: 0.9386, Train Recall: 0.9737, Train F1: 0.9463
# 			Val Loss: 0.5785, Val Acc: 0.6750, Val Precision: 0.8400, Val Recall: 0.5729, Val F1: 0.6181
#
# Epoch: 18
# 			Train Loss: 0.1906, Train Acc: 0.9803, Train Precision: 0.9605, Train Recall: 1.0000, Train F1: 0.9684
# 			Val Loss: 0.5664, Val Acc: 0.6850, Val Precision: 0.8300, Val Recall: 0.6776, Val F1: 0.7026
#
# Epoch: 1
# 			Train Loss: 0.7578, Train Acc: 0.4123, Train Precision: 1.0000, Train Recall: 0.0000, Train F1: 0.0000
# 			Val Loss: 0.7607, Val Acc: 0.3750, Val Precision: 1.0000, Val Recall: 0.0000, Val F1: 0.0000
#
# Epoch: 2
# 			Train Loss: 0.7280, Train Acc: 0.4276, Train Precision: 0.9474, Train Recall: 0.0526, Train F1: 0.0526
# 			Val Loss: 0.7346, Val Acc: 0.4050, Val Precision: 0.9000, Val Recall: 0.0500, Val F1: 0.0667
#
# Epoch: 3
# 			Train Loss: 0.7158, Train Acc: 0.4101, Train Precision: 0.6316, Train Recall: 0.0535, Train F1: 0.0887
# 			Val Loss: 0.7134, Val Acc: 0.3800, Val Precision: 0.8000, Val Recall: 0.0000, Val F1: 0.0000
#
# Epoch: 4
# 			Train Loss: 0.7034, Train Acc: 0.4803, Train Precision: 0.6544, Train Recall: 0.2799, Train F1: 0.3634
# 			Val Loss: 0.6925, Val Acc: 0.4800, Val Precision: 0.5667, Val Recall: 0.3967, Val F1: 0.4635
#
# Epoch: 5
# 			Train Loss: 0.6943, Train Acc: 0.4978, Train Precision: 0.5947, Train Recall: 0.5316, Train F1: 0.5374
# 			Val Loss: 0.6770, Val Acc: 0.6200, Val Precision: 0.6429, Val Recall: 0.8000, Val F1: 0.7027
#
# Epoch: 6
# 			Train Loss: 0.6882, Train Acc: 0.5285, Train Precision: 0.5792, Train Recall: 0.7417, Train F1: 0.6272
# 			Val Loss: 0.6606, Val Acc: 0.6950, Val Precision: 0.6557, Val Recall: 0.9500, Val F1: 0.7682
#
# Epoch: 7
# 			Train Loss: 0.6835, Train Acc: 0.5943, Train Precision: 0.6024, Train Recall: 0.8841, Train F1: 0.6901
# 			Val Loss: 0.6604, Val Acc: 0.6700, Val Precision: 0.6286, Val Recall: 0.9500, Val F1: 0.7268
#
# Epoch: 8
# 			Train Loss: 0.6739, Train Acc: 0.5702, Train Precision: 0.5971, Train Recall: 0.8837, Train F1: 0.6853
# 			Val Loss: 0.6497, Val Acc: 0.7000, Val Precision: 0.6714, Val Recall: 0.9600, Val F1: 0.7788
#
# Epoch: 9
# 			Train Loss: 0.6814, Train Acc: 0.5680, Train Precision: 0.5789, Train Recall: 0.9214, Train F1: 0.6990
# 			Val Loss: 0.6490, Val Acc: 0.6600, Val Precision: 0.6314, Val Recall: 1.0000, Val F1: 0.7583
#
# Epoch: 10
# 			Train Loss: 0.6724, Train Acc: 0.5702, Train Precision: 0.5833, Train Recall: 0.9543, Train F1: 0.7064
# 			Val Loss: 0.6530, Val Acc: 0.6050, Val Precision: 0.5943, Val Recall: 1.0000, Val F1: 0.7359
#
# Epoch: 11
# 			Train Loss: 0.6562, Train Acc: 0.5987, Train Precision: 0.6162, Train Recall: 0.9243, Train F1: 0.7159
# 			Val Loss: 0.6051, Val Acc: 0.7950, Val Precision: 0.7943, Val Recall: 0.9600, Val F1: 0.8510
#
# Epoch: 12
# 			Train Loss: 0.5747, Train Acc: 0.7785, Train Precision: 0.7573, Train Recall: 0.9204, Train F1: 0.8030
# 			Val Loss: 0.5752, Val Acc: 0.7750, Val Precision: 0.7967, Val Recall: 0.8643, Val F1: 0.7916
#
# Epoch: 13
# 			Train Loss: 0.5214, Train Acc: 0.7961, Train Precision: 0.8061, Train Recall: 0.8796, Train F1: 0.8184
# 			Val Loss: 0.5467, Val Acc: 0.7750, Val Precision: 0.8429, Val Recall: 0.8400, Val F1: 0.8258
#
# Epoch: 14
# 			Train Loss: 0.4892, Train Acc: 0.8246, Train Precision: 0.8623, Train Recall: 0.8764, Train F1: 0.8460
# 			Val Loss: 0.5511, Val Acc: 0.7350, Val Precision: 0.7833, Val Recall: 0.7214, Val F1: 0.7237
#
# Epoch: 15
# 			Train Loss: 0.3894, Train Acc: 0.9013, Train Precision: 0.8930, Train Recall: 0.9644, Train F1: 0.9105
# 			Val Loss: 0.5296, Val Acc: 0.7300, Val Precision: 0.8095, Val Recall: 0.8033, Val F1: 0.7842
#
# Epoch: 16
# 			Train Loss: 0.3283, Train Acc: 0.9101, Train Precision: 0.9123, Train Recall: 0.9561, Train F1: 0.9221
# 			Val Loss: 0.5106, Val Acc: 0.7500, Val Precision: 0.8267, Val Recall: 0.6867, Val F1: 0.7421
#
# Epoch: 17
# 			Train Loss: 0.2674, Train Acc: 0.9232, Train Precision: 0.9237, Train Recall: 0.9737, Train F1: 0.9289
# 			Val Loss: 0.5410, Val Acc: 0.7050, Val Precision: 0.8267, Val Recall: 0.6767, Val F1: 0.7390
#
# Epoch: 18
# 			Train Loss: 0.1976, Train Acc: 0.9671, Train Precision: 0.9561, Train Recall: 0.9850, Train F1: 0.9663
# 			Val Loss: 0.5168, Val Acc: 0.6700, Val Precision: 0.7048, Val Recall: 0.7167, Val F1: 0.7022

# %%
num_epochs = warmup_epochs + fine_tune_epochs

train_loss_list = np.array(train_loss_list).reshape(5, num_epochs)
train_acc_list = np.array(train_acc_list).reshape(5, num_epochs)
train_precision_list = np.array(train_precision_list).reshape(5, num_epochs)
train_recall_list = np.array(train_recall_list).reshape(5, num_epochs)
train_f1_list = np.array(train_f1_list).reshape(5, num_epochs)

val_loss_list = np.array(val_loss_list).reshape(5, num_epochs)
val_acc_list = np.array(val_acc_list).reshape(5, num_epochs)
val_precision_list = np.array(val_precision_list).reshape(5, num_epochs)
val_recall_list = np.array(val_recall_list).reshape(5, num_epochs)
val_f1_list = np.array(val_f1_list).reshape(5, num_epochs)

# %%
# plot average loss across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_loss_list, axis=0)
std_values = np.std(train_loss_list, axis=0)

plt.plot(epochs, mean_values, label='Train Loss', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(val_loss_list, axis=0)
std_values = np.std(val_loss_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Loss', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
# plt.ylim(0, 1.2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Mean and Standard Deviation over Epochs')
plt.legend()
plt.savefig('plots/resnet50/loss.png', dpi=300)

# %%
# plot average accuracy across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_acc_list, axis=0)
std_values = np.std(train_acc_list, axis=0)

plt.plot(epochs, mean_values, label='Train Accuracy', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

mean_values = np.mean(val_acc_list, axis=0)
std_values = np.std(val_acc_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Accuracy', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Mean and Standard Deviation over Epochs')
plt.legend()
plt.savefig('plots/resnet50/accuracy.png', dpi=300)

# %%
test_loss_list = []
test_acc_list = []
test_precision_list = []
test_recall_list = []
test_f1_list = []
test_auc_list = []

# test resnet18
test_resnet('resnet50')
# Out:
# Fold: 1 Test Acc: 0.6473, Test Precision: 0.6768, Test Recall: 0.7045, Test F1: 0.6898
# --------------------------------------------------
# Fold: 2 Test Acc: 0.5871, Test Precision: 0.6458, Test Recall: 0.6382, Test F1: 0.6387
# --------------------------------------------------
# Fold: 3 Test Acc: 0.6406, Test Precision: 0.7333, Test Recall: 0.6944, Test F1: 0.7097
# --------------------------------------------------
# Fold: 4 Test Acc: 0.7165, Test Precision: 0.6905, Test Recall: 0.7864, Test F1: 0.7287
# --------------------------------------------------
# Fold: 5 Test Acc: 0.4487, Test Precision: 0.5000, Test Recall: 0.4248, Test F1: 0.4567
# --------------------------------------------------

# %%
# show some images and predictions
test_loader = DataLoader(torch.utils.data.Subset(dataset, folds[0][1]), batch_size=4, shuffle=True)
model = ResNet('resnet50')
model.load_state_dict(torch.load(f'resnet50_1.pt'))

dataiter = iter(test_loader)
img, label = next(dataiter)
img = img.to(device)
label = label.to(device)
output = model(img)

fig = plt.figure(figsize=(5, 5))
for i in range(4):
	ax = fig.add_subplot(2, 2, i+1)
	ax.imshow(img[i].permute(1, 2, 0).cpu().numpy())
	ax.set_axis_off()
	ax.set_title(f'Label: {label[i].cpu().numpy()}, Pred: {(output[i].cpu().detach().numpy())[0]:.2f}')

# add title
plt.suptitle('Test Dataset Predictions')
# save image
plt.savefig('plots/resnet50/predictions.png', dpi=300)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# calculate average metrics for all folds
print('Average Test Accuracy: ', np.mean(test_acc_list))
print('Average Test Precision: ', np.mean(test_precision_list))
print('Average Test Recall: ', np.mean(test_recall_list))
print('Average Test F1: ', np.mean(test_f1_list))
print('Average Test AUC: ', np.mean(test_auc_list))
# Out:
# Average Test Accuracy:  0.6080357142857143
# Average Test Precision:  0.6492821067821067
# Average Test Recall:  0.6496646920331131
# Average Test F1:  0.6447232058507167
# Average Test AUC:  0.5926975558554506

# %%
# calculate average metrics for all folds print in latex format
print('&${0:.2f}\pm{1:.2f}$'.format(np.mean(test_acc_list), np.std(test_acc_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_precision_list), np.std(test_precision_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_recall_list), np.std(test_recall_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_f1_list), np.std(test_f1_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_auc_list), np.std(test_auc_list)))
# Out:
# &$0.61\pm0.09$ &$0.65\pm0.08$ &$0.65\pm0.12$ &$0.64\pm0.10$ &$0.59\pm0.09$

# %% [markdown]
# ### Train Vanilla Model

# %%
from torchsummary import summary

# initialize model
model = CNN()
model = model.to(device)

# print model summary
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 224, 224]             448
#               ReLU-2         [-1, 16, 224, 224]               0
#          MaxPool2d-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]           4,640
#               ReLU-5         [-1, 32, 112, 112]               0
#          MaxPool2d-6           [-1, 32, 56, 56]               0
#             Conv2d-7           [-1, 64, 56, 56]          18,496
#               ReLU-8           [-1, 64, 56, 56]               0
#          MaxPool2d-9           [-1, 64, 28, 28]               0
#            Conv2d-10          [-1, 128, 28, 28]          73,856
#              ReLU-11          [-1, 128, 28, 28]               0
#         MaxPool2d-12          [-1, 128, 14, 14]               0
#            Linear-13                  [-1, 512]      12,845,568
#              ReLU-14                  [-1, 512]               0
#            Linear-15                    [-1, 1]             513
#           Sigmoid-16                    [-1, 1]               0
# ================================================================
# Total params: 12,943,521
# Trainable params: 12,943,521
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 25.85
# Params size (MB): 49.38
# Estimated Total Size (MB): 75.80
# ----------------------------------------------------------------

# %%
# train model
train_loss_list = []
train_acc_list = []
train_precision_list = []
train_recall_list = []
train_f1_list = []

val_loss_list = []
val_acc_list = []
val_precision_list = []
val_recall_list = []
val_f1_list = []

warmup_epochs = 25
fine_tune_epochs = 0

# train cnn
train_resnet(model_name='cnn', warmup_epochs=warmup_epochs, lr=1e-5, batch_size=8)
# Out:
# Epoch: 1
# 			Train Loss: 0.6891, Train Acc: 0.5724, Train Precision: 0.6842, Train Recall: 0.8026, Train F1: 0.6005
# 			Val Loss: 0.6866, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 2
# 			Train Loss: 0.6851, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7075
# 			Val Loss: 0.6840, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6805
#
# Epoch: 3
# 			Train Loss: 0.6777, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7285
# 			Val Loss: 0.6834, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6824
#
# Epoch: 4
# 			Train Loss: 0.6815, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7136
# 			Val Loss: 0.6780, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 5
# 			Train Loss: 0.6740, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7253
# 			Val Loss: 0.6781, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7215
#
# Epoch: 6
# 			Train Loss: 0.6725, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7307
# 			Val Loss: 0.6668, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7492
#
# Epoch: 7
# 			Train Loss: 0.6795, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7106
# 			Val Loss: 0.6769, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 8
# 			Train Loss: 0.6783, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7153
# 			Val Loss: 0.6662, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7369
#
# Epoch: 9
# 			Train Loss: 0.6808, Train Acc: 0.5592, Train Precision: 0.5592, Train Recall: 1.0000, Train F1: 0.6856
# 			Val Loss: 0.6694, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7329
#
# Epoch: 10
# 			Train Loss: 0.6676, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7313
# 			Val Loss: 0.6692, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7419
#
# Epoch: 11
# 			Train Loss: 0.6715, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7174
# 			Val Loss: 0.6631, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7293
#
# Epoch: 12
# 			Train Loss: 0.6678, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7175
# 			Val Loss: 0.6657, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7382
#
# Epoch: 13
# 			Train Loss: 0.6679, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7157
# 			Val Loss: 0.6596, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 14
# 			Train Loss: 0.6687, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7127
# 			Val Loss: 0.6574, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 15
# 			Train Loss: 0.6614, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7220
# 			Val Loss: 0.6692, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 16
# 			Train Loss: 0.6556, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7192
# 			Val Loss: 0.6529, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7207
#
# Epoch: 17
# 			Train Loss: 0.6510, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7271
# 			Val Loss: 0.6517, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 18
# 			Train Loss: 0.6549, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7218
# 			Val Loss: 0.6511, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7244
#
# Epoch: 19
# 			Train Loss: 0.6569, Train Acc: 0.5592, Train Precision: 0.5592, Train Recall: 1.0000, Train F1: 0.6873
# 			Val Loss: 0.6493, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 20
# 			Train Loss: 0.6497, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7085
# 			Val Loss: 0.6463, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 21
# 			Train Loss: 0.6426, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7280
# 			Val Loss: 0.6643, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6914
#
# Epoch: 22
# 			Train Loss: 0.6448, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7057
# 			Val Loss: 0.6620, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7238
#
# Epoch: 23
# 			Train Loss: 0.6465, Train Acc: 0.5658, Train Precision: 0.5611, Train Recall: 0.9281, Train F1: 0.6845
# 			Val Loss: 0.6488, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 0.9600, Val F1: 0.7388
#
# Epoch: 24
# 			Train Loss: 0.6383, Train Acc: 0.5811, Train Precision: 0.5784, Train Recall: 0.9193, Train F1: 0.6986
# 			Val Loss: 0.6389, Val Acc: 0.6100, Val Precision: 0.6136, Val Recall: 0.9600, Val F1: 0.7437
#
# Epoch: 25
# 			Train Loss: 0.6326, Train Acc: 0.6009, Train Precision: 0.5971, Train Recall: 0.9807, Train F1: 0.7302
# 			Val Loss: 0.6451, Val Acc: 0.5950, Val Precision: 0.6021, Val Recall: 0.9714, Val F1: 0.7286
#
# Epoch: 1
# 			Train Loss: 0.6896, Train Acc: 0.5526, Train Precision: 0.8026, Train Recall: 0.5526, Train F1: 0.4310
# 			Val Loss: 0.6792, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 2
# 			Train Loss: 0.6811, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7109
# 			Val Loss: 0.6734, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7329
#
# Epoch: 3
# 			Train Loss: 0.6765, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7221
# 			Val Loss: 0.6753, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7201
#
# Epoch: 4
# 			Train Loss: 0.6791, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7105
# 			Val Loss: 0.6625, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7402
#
# Epoch: 5
# 			Train Loss: 0.6743, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7228
# 			Val Loss: 0.6600, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7402
#
# Epoch: 6
# 			Train Loss: 0.6754, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7121
# 			Val Loss: 0.6634, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7419
#
# Epoch: 7
# 			Train Loss: 0.6699, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7192
# 			Val Loss: 0.6669, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 8
# 			Train Loss: 0.6657, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7215
# 			Val Loss: 0.6562, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7329
#
# Epoch: 9
# 			Train Loss: 0.6671, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7235
# 			Val Loss: 0.6443, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 10
# 			Train Loss: 0.6657, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7154
# 			Val Loss: 0.6487, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7449
#
# Epoch: 11
# 			Train Loss: 0.6597, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7298
# 			Val Loss: 0.6572, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6900
#
# Epoch: 12
# 			Train Loss: 0.6577, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7248
# 			Val Loss: 0.6484, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 13
# 			Train Loss: 0.6614, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7138
# 			Val Loss: 0.6367, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7263
#
# Epoch: 14
# 			Train Loss: 0.6570, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7080
# 			Val Loss: 0.6327, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7369
#
# Epoch: 15
# 			Train Loss: 0.6540, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7231
# 			Val Loss: 0.6388, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7201
#
# Epoch: 16
# 			Train Loss: 0.6448, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7245
# 			Val Loss: 0.6279, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7329
#
# Epoch: 17
# 			Train Loss: 0.6487, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7261
# 			Val Loss: 0.6180, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7492
#
# Epoch: 18
# 			Train Loss: 0.6433, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7190
# 			Val Loss: 0.6263, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7353
#
# Epoch: 19
# 			Train Loss: 0.6425, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7131
# 			Val Loss: 0.6241, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7238
#
# Epoch: 20
# 			Train Loss: 0.6401, Train Acc: 0.5943, Train Precision: 0.5912, Train Recall: 0.9381, Train F1: 0.7000
# 			Val Loss: 0.6114, Val Acc: 0.6100, Val Precision: 0.6029, Val Recall: 0.9333, Val F1: 0.7206
#
# Epoch: 21
# 			Train Loss: 0.6396, Train Acc: 0.5877, Train Precision: 0.5855, Train Recall: 0.9632, Train F1: 0.7178
# 			Val Loss: 0.6123, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7367
#
# Epoch: 22
# 			Train Loss: 0.6327, Train Acc: 0.5987, Train Precision: 0.5987, Train Recall: 0.9605, Train F1: 0.7242
# 			Val Loss: 0.6066, Val Acc: 0.6750, Val Precision: 0.6786, Val Recall: 0.9714, Val F1: 0.7635
#
# Epoch: 23
# 			Train Loss: 0.6307, Train Acc: 0.6140, Train Precision: 0.5971, Train Recall: 0.9868, Train F1: 0.7276
# 			Val Loss: 0.6096, Val Acc: 0.5950, Val Precision: 0.6071, Val Recall: 0.9500, Val F1: 0.7061
#
# Epoch: 24
# 			Train Loss: 0.6317, Train Acc: 0.6031, Train Precision: 0.5949, Train Recall: 0.9395, Train F1: 0.7124
# 			Val Loss: 0.6026, Val Acc: 0.6600, Val Precision: 0.6833, Val Recall: 0.9500, Val F1: 0.7725
#
# Epoch: 25
# 			Train Loss: 0.6263, Train Acc: 0.6206, Train Precision: 0.6258, Train Recall: 0.9346, Train F1: 0.7174
# 			Val Loss: 0.6031, Val Acc: 0.6050, Val Precision: 0.6050, Val Recall: 0.9500, Val F1: 0.7285
#
# Epoch: 1
# 			Train Loss: 0.6859, Train Acc: 0.5724, Train Precision: 0.5592, Train Recall: 0.9474, Train F1: 0.6827
# 			Val Loss: 0.6795, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7064
#
# Epoch: 2
# 			Train Loss: 0.6809, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7215
# 			Val Loss: 0.6839, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6877
#
# Epoch: 3
# 			Train Loss: 0.6803, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7140
# 			Val Loss: 0.6743, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7449
#
# Epoch: 4
# 			Train Loss: 0.6760, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7265
# 			Val Loss: 0.6738, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7329
#
# Epoch: 5
# 			Train Loss: 0.6889, Train Acc: 0.5592, Train Precision: 0.5592, Train Recall: 1.0000, Train F1: 0.6905
# 			Val Loss: 0.6837, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6877
#
# Epoch: 6
# 			Train Loss: 0.6790, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7225
# 			Val Loss: 0.6735, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7419
#
# Epoch: 7
# 			Train Loss: 0.6864, Train Acc: 0.5592, Train Precision: 0.5592, Train Recall: 1.0000, Train F1: 0.6885
# 			Val Loss: 0.6674, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7492
#
# Epoch: 8
# 			Train Loss: 0.6792, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7140
# 			Val Loss: 0.6814, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6967
#
# Epoch: 9
# 			Train Loss: 0.6813, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7136
# 			Val Loss: 0.6669, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7369
#
# Epoch: 10
# 			Train Loss: 0.6829, Train Acc: 0.5592, Train Precision: 0.5592, Train Recall: 1.0000, Train F1: 0.6802
# 			Val Loss: 0.6705, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7419
#
# Epoch: 11
# 			Train Loss: 0.6785, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7116
# 			Val Loss: 0.6710, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 12
# 			Train Loss: 0.6713, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7268
# 			Val Loss: 0.6691, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7449
#
# Epoch: 13
# 			Train Loss: 0.6777, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7111
# 			Val Loss: 0.6538, Val Acc: 0.6250, Val Precision: 0.6250, Val Recall: 1.0000, Val F1: 0.7538
#
# Epoch: 14
# 			Train Loss: 0.6746, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7166
# 			Val Loss: 0.6612, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7316
#
# Epoch: 15
# 			Train Loss: 0.6680, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7284
# 			Val Loss: 0.6694, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7215
#
# Epoch: 16
# 			Train Loss: 0.6668, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7270
# 			Val Loss: 0.6546, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7484
#
# Epoch: 17
# 			Train Loss: 0.6654, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7212
# 			Val Loss: 0.6581, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7214
#
# Epoch: 18
# 			Train Loss: 0.6738, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7099
# 			Val Loss: 0.6548, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7329
#
# Epoch: 19
# 			Train Loss: 0.6646, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7175
# 			Val Loss: 0.6582, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 20
# 			Train Loss: 0.6595, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7177
# 			Val Loss: 0.6496, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 21
# 			Train Loss: 0.6587, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7169
# 			Val Loss: 0.6590, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6944
#
# Epoch: 22
# 			Train Loss: 0.6518, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7264
# 			Val Loss: 0.6527, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7177
#
# Epoch: 23
# 			Train Loss: 0.6623, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7122
# 			Val Loss: 0.6340, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 24
# 			Train Loss: 0.6565, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7112
# 			Val Loss: 0.6311, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 25
# 			Train Loss: 0.6560, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7141
# 			Val Loss: 0.6364, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7329
#
# Epoch: 1
# 			Train Loss: 0.6948, Train Acc: 0.5044, Train Precision: 0.6952, Train Recall: 0.6404, Train F1: 0.4583
# 			Val Loss: 0.6813, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7263
#
# Epoch: 2
# 			Train Loss: 0.6809, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7270
# 			Val Loss: 0.6766, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7449
#
# Epoch: 3
# 			Train Loss: 0.6801, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7105
# 			Val Loss: 0.6741, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7419
#
# Epoch: 4
# 			Train Loss: 0.6777, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7184
# 			Val Loss: 0.6717, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7382
#
# Epoch: 5
# 			Train Loss: 0.6757, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7170
# 			Val Loss: 0.6791, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6877
#
# Epoch: 6
# 			Train Loss: 0.6713, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7234
# 			Val Loss: 0.6648, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7316
#
# Epoch: 7
# 			Train Loss: 0.6631, Train Acc: 0.5921, Train Precision: 0.5921, Train Recall: 1.0000, Train F1: 0.7228
# 			Val Loss: 0.6697, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7238
#
# Epoch: 8
# 			Train Loss: 0.6645, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7228
# 			Val Loss: 0.6549, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 9
# 			Train Loss: 0.6641, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7084
# 			Val Loss: 0.6588, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 10
# 			Train Loss: 0.6545, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7215
# 			Val Loss: 0.6552, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7455
#
# Epoch: 11
# 			Train Loss: 0.6517, Train Acc: 0.5811, Train Precision: 0.5811, Train Recall: 1.0000, Train F1: 0.7100
# 			Val Loss: 0.6462, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7492
#
# Epoch: 12
# 			Train Loss: 0.6586, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7097
# 			Val Loss: 0.6522, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7449
#
# Epoch: 13
# 			Train Loss: 0.6484, Train Acc: 0.5702, Train Precision: 0.5702, Train Recall: 1.0000, Train F1: 0.7106
# 			Val Loss: 0.6547, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 14
# 			Train Loss: 0.6481, Train Acc: 0.6162, Train Precision: 0.6118, Train Recall: 0.9367, Train F1: 0.7164
# 			Val Loss: 0.6548, Val Acc: 0.6100, Val Precision: 0.6107, Val Recall: 0.8648, Val F1: 0.7075
#
# Epoch: 15
# 			Train Loss: 0.6432, Train Acc: 0.6118, Train Precision: 0.6003, Train Recall: 0.9192, Train F1: 0.6883
# 			Val Loss: 0.6494, Val Acc: 0.5850, Val Precision: 0.6500, Val Recall: 0.8333, Val F1: 0.7015
#
# Epoch: 16
# 			Train Loss: 0.6297, Train Acc: 0.6316, Train Precision: 0.6474, Train Recall: 0.8539, Train F1: 0.7180
# 			Val Loss: 0.6567, Val Acc: 0.5650, Val Precision: 0.5690, Val Recall: 0.8100, Val F1: 0.6545
#
# Epoch: 17
# 			Train Loss: 0.6322, Train Acc: 0.6316, Train Precision: 0.6395, Train Recall: 0.9482, Train F1: 0.7488
# 			Val Loss: 0.6443, Val Acc: 0.5850, Val Precision: 0.6029, Val Recall: 0.8600, Val F1: 0.6993
#
# Epoch: 18
# 			Train Loss: 0.6245, Train Acc: 0.6382, Train Precision: 0.6288, Train Recall: 0.9263, Train F1: 0.7315
# 			Val Loss: 0.6457, Val Acc: 0.5950, Val Precision: 0.6090, Val Recall: 0.8700, Val F1: 0.7105
#
# Epoch: 19
# 			Train Loss: 0.6321, Train Acc: 0.5965, Train Precision: 0.6224, Train Recall: 0.7557, Train F1: 0.6677
# 			Val Loss: 0.6425, Val Acc: 0.6100, Val Precision: 0.6790, Val Recall: 0.7600, Val F1: 0.6961
#
# Epoch: 20
# 			Train Loss: 0.6292, Train Acc: 0.6031, Train Precision: 0.6176, Train Recall: 0.7984, Train F1: 0.6600
# 			Val Loss: 0.6382, Val Acc: 0.6200, Val Precision: 0.6286, Val Recall: 0.8648, Val F1: 0.7048
#
# Epoch: 21
# 			Train Loss: 0.6187, Train Acc: 0.6316, Train Precision: 0.6629, Train Recall: 0.7719, Train F1: 0.6915
# 			Val Loss: 0.6468, Val Acc: 0.5950, Val Precision: 0.6267, Val Recall: 0.8200, Val F1: 0.6991
#
# Epoch: 22
# 			Train Loss: 0.6214, Train Acc: 0.6140, Train Precision: 0.6529, Train Recall: 0.7808, Train F1: 0.6841
# 			Val Loss: 0.6477, Val Acc: 0.5800, Val Precision: 0.5962, Val Recall: 0.7214, Val F1: 0.6407
#
# Epoch: 23
# 			Train Loss: 0.6163, Train Acc: 0.6338, Train Precision: 0.6225, Train Recall: 0.8912, Train F1: 0.7139
# 			Val Loss: 0.6361, Val Acc: 0.5700, Val Precision: 0.5971, Val Recall: 0.8867, Val F1: 0.7026
#
# Epoch: 24
# 			Train Loss: 0.6171, Train Acc: 0.6294, Train Precision: 0.6813, Train Recall: 0.8024, Train F1: 0.7019
# 			Val Loss: 0.6441, Val Acc: 0.5800, Val Precision: 0.6300, Val Recall: 0.6467, Val F1: 0.6276
#
# Epoch: 25
# 			Train Loss: 0.6149, Train Acc: 0.6272, Train Precision: 0.6452, Train Recall: 0.8256, Train F1: 0.7003
# 			Val Loss: 0.6365, Val Acc: 0.6350, Val Precision: 0.6505, Val Recall: 0.8167, Val F1: 0.7035
#
# Epoch: 1
# 			Train Loss: 0.6866, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7179
# 			Val Loss: 0.6815, Val Acc: 0.5650, Val Precision: 0.5650, Val Recall: 1.0000, Val F1: 0.6944
#
# Epoch: 2
# 			Train Loss: 0.6780, Train Acc: 0.5768, Train Precision: 0.5768, Train Recall: 1.0000, Train F1: 0.7138
# 			Val Loss: 0.6706, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7382
#
# Epoch: 3
# 			Train Loss: 0.6690, Train Acc: 0.5987, Train Precision: 0.5987, Train Recall: 1.0000, Train F1: 0.7276
# 			Val Loss: 0.6612, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 4
# 			Train Loss: 0.6710, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7220
# 			Val Loss: 0.6572, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7340
#
# Epoch: 5
# 			Train Loss: 0.6685, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7254
# 			Val Loss: 0.6638, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7201
#
# Epoch: 6
# 			Train Loss: 0.6651, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7294
# 			Val Loss: 0.6595, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 7
# 			Train Loss: 0.6666, Train Acc: 0.5768, Train Precision: 0.5768, Train Recall: 1.0000, Train F1: 0.7072
# 			Val Loss: 0.6541, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7177
#
# Epoch: 8
# 			Train Loss: 0.6547, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7248
# 			Val Loss: 0.6374, Val Acc: 0.6250, Val Precision: 0.6250, Val Recall: 1.0000, Val F1: 0.7501
#
# Epoch: 9
# 			Train Loss: 0.6518, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7282
# 			Val Loss: 0.6349, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7353
#
# Epoch: 10
# 			Train Loss: 0.6524, Train Acc: 0.5768, Train Precision: 0.5768, Train Recall: 1.0000, Train F1: 0.7183
# 			Val Loss: 0.6276, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7382
#
# Epoch: 11
# 			Train Loss: 0.6356, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7232
# 			Val Loss: 0.6179, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7382
#
# Epoch: 12
# 			Train Loss: 0.6365, Train Acc: 0.5987, Train Precision: 0.5987, Train Recall: 1.0000, Train F1: 0.7165
# 			Val Loss: 0.6029, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 13
# 			Train Loss: 0.6338, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7310
# 			Val Loss: 0.5893, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7388
#
# Epoch: 14
# 			Train Loss: 0.6346, Train Acc: 0.5768, Train Precision: 0.5768, Train Recall: 1.0000, Train F1: 0.7169
# 			Val Loss: 0.5939, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7369
#
# Epoch: 15
# 			Train Loss: 0.6229, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7266
# 			Val Loss: 0.5926, Val Acc: 0.5950, Val Precision: 0.5950, Val Recall: 1.0000, Val F1: 0.7329
#
# Epoch: 16
# 			Train Loss: 0.6244, Train Acc: 0.5877, Train Precision: 0.5877, Train Recall: 1.0000, Train F1: 0.7263
# 			Val Loss: 0.5973, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7238
#
# Epoch: 17
# 			Train Loss: 0.6173, Train Acc: 0.5987, Train Precision: 0.5987, Train Recall: 1.0000, Train F1: 0.7243
# 			Val Loss: 0.5715, Val Acc: 0.6100, Val Precision: 0.6100, Val Recall: 1.0000, Val F1: 0.7521
#
# Epoch: 18
# 			Train Loss: 0.6237, Train Acc: 0.5768, Train Precision: 0.5768, Train Recall: 1.0000, Train F1: 0.7104
# 			Val Loss: 0.5765, Val Acc: 0.5800, Val Precision: 0.5800, Val Recall: 1.0000, Val F1: 0.7267
#
# Epoch: 19
# 			Train Loss: 0.6135, Train Acc: 0.6206, Train Precision: 0.6234, Train Recall: 0.8982, Train F1: 0.7191
# 			Val Loss: 0.5825, Val Acc: 0.7600, Val Precision: 0.7048, Val Recall: 0.9000, Val F1: 0.7832
#
# Epoch: 20
# 			Train Loss: 0.6239, Train Acc: 0.5789, Train Precision: 0.6194, Train Recall: 0.8518, Train F1: 0.6797
# 			Val Loss: 0.5610, Val Acc: 0.7750, Val Precision: 0.7350, Val Recall: 0.9600, Val F1: 0.8067
#
# Epoch: 21
# 			Train Loss: 0.6086, Train Acc: 0.6579, Train Precision: 0.6807, Train Recall: 0.8096, Train F1: 0.7218
# 			Val Loss: 0.5746, Val Acc: 0.8250, Val Precision: 0.8529, Val Recall: 0.8700, Val F1: 0.8444
#
# Epoch: 22
# 			Train Loss: 0.6164, Train Acc: 0.6228, Train Precision: 0.6252, Train Recall: 0.8367, Train F1: 0.7002
# 			Val Loss: 0.5598, Val Acc: 0.7450, Val Precision: 0.7124, Val Recall: 0.9600, Val F1: 0.8085
#
# Epoch: 23
# 			Train Loss: 0.6164, Train Acc: 0.6228, Train Precision: 0.6276, Train Recall: 0.8244, Train F1: 0.6691
# 			Val Loss: 0.5752, Val Acc: 0.8250, Val Precision: 0.8267, Val Recall: 0.9029, Val F1: 0.8472
#
# Epoch: 24
# 			Train Loss: 0.5993, Train Acc: 0.6645, Train Precision: 0.6736, Train Recall: 0.8149, Train F1: 0.7202
# 			Val Loss: 0.5680, Val Acc: 0.8200, Val Precision: 0.8200, Val Recall: 0.8833, Val F1: 0.8366
#
# Epoch: 25
# 			Train Loss: 0.6056, Train Acc: 0.6579, Train Precision: 0.6789, Train Recall: 0.7977, Train F1: 0.7220
# 			Val Loss: 0.5718, Val Acc: 0.8250, Val Precision: 0.8500, Val Recall: 0.9000, Val F1: 0.8714

# %%
# reshape lists
num_epochs = warmup_epochs + fine_tune_epochs

train_loss_list = np.array(train_loss_list).reshape(5, num_epochs)
train_acc_list = np.array(train_acc_list).reshape(5, num_epochs)
train_precision_list = np.array(train_precision_list).reshape(5, num_epochs)
train_recall_list = np.array(train_recall_list).reshape(5, num_epochs)
train_f1_list = np.array(train_f1_list).reshape(5, num_epochs)

val_loss_list = np.array(val_loss_list).reshape(5, num_epochs)
val_acc_list = np.array(val_acc_list).reshape(5, num_epochs)
val_precision_list = np.array(val_precision_list).reshape(5, num_epochs)
val_recall_list = np.array(val_recall_list).reshape(5, num_epochs)
val_f1_list = np.array(val_f1_list).reshape(5, num_epochs)

# %%
# plot average loss across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_loss_list, axis=0)
std_values = np.std(train_loss_list, axis=0)

plt.plot(epochs, mean_values, label='Train Loss', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(val_loss_list, axis=0)
std_values = np.std(val_loss_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Loss', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
plt.xticks(np.arange(1, num_epochs+1, 2.0))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Vanilla CNN Loss over Epochs')
plt.legend()
plt.savefig('plots/cnn/loss.png', dpi=300)

# %%
# plot average accuracy across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_acc_list, axis=0)
std_values = np.std(train_acc_list, axis=0)

plt.plot(epochs, mean_values, label='Train Accuracy', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(val_acc_list, axis=0)
std_values = np.std(val_acc_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Accuracy', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
plt.xticks(np.arange(1, num_epochs+1, 2.0))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Vanilla CNN Accuracy over Epochs')
plt.legend()
plt.savefig('plots/cnn/accuracy.png', dpi=300)

# %%
# plot average precision across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_precision_list, axis=0)
std_values = np.std(train_precision_list, axis=0)

plt.plot(epochs, mean_values, label='Train Precision', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(val_precision_list, axis=0)
std_values = np.std(val_precision_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Precision', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
plt.xticks(np.arange(1, num_epochs+1, 2.0))
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Vanilla CNN Precision over Epochs')
plt.legend()
plt.savefig('plots/cnn/precision.png', dpi=300)

# %%
# plot average recall across 5 folds
plt.figure(figsize=(8, 6))

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(train_recall_list, axis=0)
std_values = np.std(train_recall_list, axis=0)

plt.plot(epochs, mean_values, label='Train Recall', color='blue')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='blue')

epochs = np.arange(1, num_epochs+1)  # Epochs
mean_values = np.mean(val_recall_list, axis=0)
std_values = np.std(val_recall_list, axis=0)

plt.plot(epochs, mean_values, label='Validation Recall', color='orange')
plt.fill_between(epochs, mean_values - std_values, mean_values + std_values, alpha=0.2, color='orange')

# Set plot labels and title
plt.xlim(1, num_epochs)
plt.xticks(np.arange(1, num_epochs+1, 2.0))
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Vanilla CNN Recall over Epochs')
plt.legend()
plt.savefig('plots/cnn/recall.png', dpi=300)

# %%
# save metrics
np.save('plots/cnn/train_loss.npy', train_loss_list)
np.save('plots/cnn/train_acc.npy', train_acc_list)
np.save('plots/cnn/train_precision.npy', train_precision_list)
np.save('plots/cnn/train_recall.npy', train_recall_list)
np.save('plots/cnn/train_f1.npy', train_f1_list)

np.save('plots/cnn/val_loss.npy', val_loss_list)
np.save('plots/cnn/val_acc.npy', val_acc_list)
np.save('plots/cnn/val_precision.npy', val_precision_list)
np.save('plots/cnn/val_recall.npy', val_recall_list)
np.save('plots/cnn/val_f1.npy', val_f1_list)

# %%
# test vanilla cnn
test_loss_list = []
test_acc_list = []
test_precision_list = []
test_recall_list = []
test_f1_list = []
test_acc_list = []

test_resnet('cnn')
# Out:
# Fold: 1 Test Acc: 0.5982, Test Precision: 0.5859, Test Recall: 0.9750, Test F1: 0.7300
# --------------------------------------------------
# Fold: 2 Test Acc: 0.7254, Test Precision: 0.7292, Test Recall: 0.8917, Test F1: 0.7917
# --------------------------------------------------
# Fold: 3 Test Acc: 0.5625, Test Precision: 0.5625, Test Recall: 1.0000, Test F1: 0.7179
# --------------------------------------------------
# Fold: 4 Test Acc: 0.5938, Test Precision: 0.5968, Test Recall: 0.9375, Test F1: 0.7292
# --------------------------------------------------
# Fold: 5 Test Acc: 0.4844, Test Precision: 0.5417, Test Recall: 0.7418, Test F1: 0.6260
# --------------------------------------------------

# %%
# save metrics
np.save('plots/cnn/test_acc.npy', test_acc_list)
np.save('plots/cnn/test_precision.npy', test_precision_list)
np.save('plots/cnn/test_recall.npy', test_recall_list)
np.save('plots/cnn/test_f1.npy', test_f1_list)
np.save('plots/cnn/test_auc.npy', test_auc_list)

# %%
# show some images and predictions
test_loader = DataLoader(torch.utils.data.Subset(dataset, folds[0][1]), batch_size=4, shuffle=True)
model = CNN()
model.load_state_dict(torch.load(f'cnn_1.pt'))

dataiter = iter(test_loader)
img, label = next(dataiter)
img = img.to(device)
label = label.to(device)
output = model(img)

fig = plt.figure(figsize=(5, 5))
for i in range(4):
	ax = fig.add_subplot(2, 2, i+1)
	ax.imshow(img[i].permute(1, 2, 0).cpu().numpy())
	ax.set_axis_off()
	ax.set_title(f'Label: {label[i].cpu().numpy()}, Pred: {(output[i].cpu().detach().numpy())[0]:.2f}')

# add title
plt.suptitle('Test Dataset Predictions')
# save image
plt.savefig('plots/cnn/predictions.png', dpi=300)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# calculate average metrics for all folds
print('Average Test Accuracy: ', np.mean(test_acc_list))
print('Average Test Precision: ', np.mean(test_precision_list))
print('Average Test Recall: ', np.mean(test_recall_list))
print('Average Test F1: ', np.mean(test_f1_list))
print('Average Test AUC: ', np.mean(test_auc_list))
# Out:
# Average Test Accuracy:  0.5928571428571429
# Average Test Precision:  0.6032095490716181
# Average Test Recall:  0.9091993464052287
# Average Test F1:  0.7189596622889306
# Average Test AUC:  0.5327162992952467

# %%
# calculate average metrics for all folds print in latex format
print('&${0:.2f}\pm{1:.2f}$'.format(np.mean(test_acc_list), np.std(test_acc_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_precision_list), np.std(test_precision_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_recall_list), np.std(test_recall_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_f1_list), np.std(test_f1_list)) + ' &${0:.2f}\pm{1:.2f}$'.format(np.mean(test_auc_list), np.std(test_auc_list)))
# Out:
# &$0.59\pm0.08$ &$0.60\pm0.07$ &$0.91\pm0.09$ &$0.72\pm0.05$ &$0.53\pm0.06$

# %% [markdown]
# ### Activation Visualization

# %%
# Load a pre-trained model
model = CNN()
model.load_state_dict(torch.load('cnn_1.pt'))
# Out:
# <All keys matched successfully>

# %%
test_loader = DataLoader(torch.utils.data.Subset(dataset, folds[0][1]), batch_size=1, shuffle=True)
dataiter = iter(test_loader)
img, label = next(dataiter)

# %%
# Function to get activations from a specific layer
def get_activations(image, model, layer_num):
    activations = None
    model_children = list(model.children())

    activations = torch.zeros(1, model_children[layer_num].out_channels, 0, 0)
    def hook_fn(module, input, output):
        nonlocal activations
        activations = output.detach()
    model_children[layer_num].register_forward_hook(hook_fn)
    model(image)
    return activations

# Choose a layer number to visualize its features (e.g., layer 4 in ResNet)
layer_number = 3
activations = get_activations(img, model, layer_number)[0]

# Visualize some of the activation maps
num_features = activations.size(0)
plt.figure(figsize=(12, 6))
for i in range(min(32, num_features)):
    plt.subplot(4, 8, i+1)
    plt.imshow(activations[i].cpu(), cmap='viridis')
    plt.axis('off')
plt.tight_layout()
plt.savefig(f'plots/cnn/activations_layer-{layer_number}.png', dpi=300)

# %%
img, label = next(dataiter)
label
# Out:
# tensor([1])

# %%
img = img.to(device)
label = label.to(device)
output = model(img)
output
# Out:
# tensor([[0.5049]], grad_fn=<SigmoidBackward0>)

# %%
# Choose a layer number to visualize its features (e.g., layer 4 in ResNet)
layer_number = 0
activations = get_activations(img, model, layer_number)[0]

# Visualize some of the activation maps
num_features = activations.size(0)
plt.figure(figsize=(12, 6))
for i in range(min(32, num_features)):
    plt.subplot(4, 8, i+1)
    plt.imshow(activations[i].cpu(), cmap='viridis')
    plt.axis('off')
plt.tight_layout()
plt.savefig(f'plots/cnn/activations_layer-{layer_number}_label-1.png', dpi=300)
